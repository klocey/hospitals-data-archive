# %% [markdown]
# # Generate Payment and Value of Care dataframe

# %%
import pandas as pd
import numpy as np
import warnings
from IPython.utils import io
import sys
import time

warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

main_dir = '~/Desktop/Rush/CMS_HospitalArchives/'

# %% [markdown]
# ## Define Custom Functions

# %%
def curate(df):

    try:
        df = df[df['Facility ID'] != np.nan]
        df['Facility ID'] = df['Facility ID'].values.astype(str)
        
        ids = df['Facility ID'].tolist()
        ids2 = []
        for i in ids:
            if len(i) < 6:
                i = '0' + i
            ids2.append(i)
        df['Facility ID'] = ids2
        
    except:
        pass
    try:
        df = df[df['Facility Name'] != np.nan]
    except:
        pass
    
    for c in list(df):    
        try:
            df[c] = df[c].str.replace("\t","")
        except:
            pass

    return df


def rename_and_fill(df):
    
    cols1 = ['Provider ID', "Measure Start Date", "Measure End Date",
             'Hospital Name', 'Hospital name', 'County name',
             'Phone number', 'Payment measure name', 'Payment measure ID', 
             'Payment category', 'Lower estimate', 'Higher estimate', 
             'Payment footnote', 'Value of care display name', 
             'Value of care display ID', 'Value of care category', 
             'Value of care footnote', 
             'Measure start date', 'Measure end date',
             'Measure ID',
             'Measure name', 'Category', 'Footnote',
             'Address 1', 'City/Town', 'County/Parish',
             'Telephone Number',
             ]
    
    
    cols2 = ['Facility ID', "Start Date", "End Date",
             'Facility Name', 'Facility Name', 'County Name',
             'Phone Number', 'Payment Measure Name', 'Payment Measure ID', 
             'Payment Category', 'Lower Estimate', 'Higher Estimate', 
             'Payment Footnote', 'Value of Care Display Name', 
             'Value of Care Display ID', 'Value of Care Category', 
             'Value of Care Footnote', 
             'Start Date', 'End Date',
             'Payment Measure ID',
             'Payment Measure Name', 'Payment Category', 'Payment Footnote',
             'Address', 'City', 'County Name',
             'Phone Number',
             ]
    
    for i, col in enumerate(cols1):
        if col in list(df):
            df.rename(columns={col: cols2[i]}, inplace=True)
                    
    l = list(df)
    l = list(set([x for x in l if l.count(x) > 1]))
    if len(l) > 0:
        print('duplicates:', l)
        sys.exit()
        
    return df


def process2(df, lists, yr, mo):
    df = rename_and_fill(df)
    df = curate(df)
    lists.append(list(df))
    df['file_month'] = [mo]* df.shape[0]
    df['file_year'] = [yr]* df.shape[0]
    df = df.reindex(sorted(df.columns), axis=1)
    return df, lists

# %% [markdown]
# ## Load Files

# %%
df_list = []
lists = []

yrs = ['2023', '2023', '2023', '2023',
       '2022', '2022', '2022', '2022',
       '2021','2021','2021', '2021', '2021',
       '2020', '2020', '2020', '2020', 
       '2019', '2019', '2019', '2019', 
       '2018', '2018', '2018', '2018',
       '2017', '2017', '2017',
       '2016', '2016', '2016', '2016',
       '2015', '2015', '2015',
       ]

mos = ['01', '04', '07', '10',
       '01', '04', '07', '10',
       '01', '03', '04', '07', '10', 
       '10', '07', '04', '01', 
       '10', '07', '04', '03', 
       '10', '07', '05', '01',
       '10', '07', '04',
       '12', '11', '08', '05',
       '12', '10', '07',
       ]

subdirs = ['2023/hospitals_01_2023/Payment_and_Value_of_Care-Hospital.csv', 
           '2023/hospitals_04_2023/Payment_and_Value_of_Care-Hospital.csv',
           '2023/hospitals_07_2023/Payment_and_Value_of_Care-Hospital.csv',
           '2023/hospitals_10_2023/Payment_and_Value_of_Care-Hospital.csv',
           
           '2022/hospitals_01_2022/Payment_and_Value_of_Care-Hospital.csv', 
           '2022/hospitals_04_2022/Payment_and_Value_of_Care-Hospital.csv',
           '2022/hospitals_07_2022/Payment_and_Value_of_Care-Hospital.csv',
           '2022/hospitals_10_2022/Payment_and_Value_of_Care-Hospital.csv',
           
           '2021/hospitals_01_2021/Payment_and_Value_of_Care-Hospital.csv',
           '2021/hospitals_03_2021/Payment_and_Value_of_Care-Hospital.csv',
           '2021/hospitals_04_2021/Payment_and_Value_of_Care-Hospital.csv',
           '2021/hospitals_07_2021/Payment_and_Value_of_Care-Hospital.csv',
           '2021/hospitals_10_2021/Payment_and_Value_of_Care-Hospital.csv',
           
           '2020/hospitals_archive_10_2020/Payment_and_value_of_care_Hospital.csv',
           '2020/hospitals_archive_07_2020/Payment_and_value_of_care_Hospital.csv',
           '2020/HOSArchive_Revised_Flatfiles_20200422/Payment and Value of Care - Hospital.csv',
           '2020/HOSArchive_Revised_Flatfiles_20200129/Payment and Value of Care - Hospital.csv',
           
           '2019/HOSArchive_Revised_Flatfiles_20191030/Payment and Value of Care - Hospital.csv',
           '2019/HOSArchive_Revised_Flatfiles_20190702/Payment and Value of Care - Hospital.csv',
           '2019/HOSArchive_Revised_FlatFiles_20190424/Payment and Value of Care - Hospital.csv',
           '2019/HOSArchive_Revised_Flatfiles_20190321/Payment and Value of Care - Hospital.csv',
           
           '2018/HOSArchive_Revised_FlatFiles_20181031/Payment and Value of Care - Hospital.csv',
           '2018/HOSArchive_Revised_FlatFiles_20180725/Payment and Value of Care - Hospital.csv', 
           '2018/HOSArchive_Revised_FlatFiles_20180523/Payment and Value of Care - Hospital.csv',
           '2018/HOSArchive_Revised_FlatFiles_20180126/Payment and Value of Care - Hospital.csv',
           
           '2017/HOSArchive_Revised_FlatFiles_20171024/Payment and Value of Care - Hospital.csv',
           '2017/HOSArchive_Revised_FlatFiles_20170726/Payment and Value of Care - Hospital.csv', 
           '2017/HOSArchive_Revised_Flatfiles_20170428/Payment and Value of Care - Hospital.csv', 
           
           '2016/HOSArchive_Revised_Flatfiles_20161219/Payment and Value of Care - Hospital.csv',
           '2016/Hospital_Revised_FlatFiles_20161110/Payment and Value of Care - Hospital.csv', 
           '2016/HOSArchive_Revised_FlatFiles_20160810/Payment and Value of Care - Hospital.csv',
           '2016/HOSArchive_Revised_FlatFiles_20160504/Payment and Value of Care - Hospital.csv',
           
           '2015/HOSArchive_Revised_FlatFiles_20151210/Payment and Value of Care - Hospital.csv',
           '2015/HOSArchive_Revised_FlatFiles_20151008/Payment and Value of Care - Hospital.csv',
           '2015/HOSArchive_Revised_FlatFiles_20150716/Payment - Hospital.csv',
           
           ]

for i, subdir in enumerate(subdirs):
    with io.capture_output() as captured: df = pd.read_csv(main_dir + subdir, encoding = "ISO-8859-1")
    print(subdir + ' :  (rows, columns) =', df.shape)
    df, lists = process2(df, lists, yrs[i], mos[i])
    df_list.append(df)

df = pd.concat(df_list)

print('df.shape:', df.shape)
df = df[~df['Denominator'].isin([np.nan, float("NaN"), 'Not Available'])]
print('df.shape:', df.shape)

df.head()
# Out:
# 2023/hospitals_01_2023/Payment_and_Value_of_Care-Hospital.csv :  (rows, columns) = (18704, 22)
# 2023/hospitals_04_2023/Payment_and_Value_of_Care-Hospital.csv :  (rows, columns) = (18692, 22)
# 2023/hospitals_07_2023/Payment_and_Value_of_Care-Hospital.csv :  (rows, columns) = (18664, 22)
# 2023/hospitals_10_2023/Payment_and_Value_of_Care-Hospital.csv :  (rows, columns) = (18664, 22)
# 2022/hospitals_01_2022/Payment_and_Value_of_Care-Hospital.csv :  (rows, columns) = (18704, 22)
# 2022/hospitals_04_2022/Payment_and_Value_of_Care-Hospital.csv :  (rows, columns) = (18704, 22)
# 2022/hospitals_07_2022/Payment_and_Value_of_Care-Hospital.csv :  (rows, columns) = (18684, 22)
# 2022/hospitals_10_2022/Payment_and_Value_of_Care-Hospital.csv :  (rows, columns) = (18692, 22)
# 2021/hospitals_01_2021/Payment_and_Value_of_Care-Hospital.csv :  (rows, columns) = (18840, 22)
# 2021/hospitals_03_2021/Payment_and_Value_of_Care-Hospital.csv :  (rows, columns) = (18840, 22)
# 2021/hospitals_04_2021/Payment_and_Value_of_Care-Hospital.csv :  (rows, columns) = (18960, 22)
# 2021/hospitals_07_2021/Payment_and_Value_of_Care-Hospital.csv :  (rows, columns) = (18776, 22)
# 2021/hospitals_10_2021/Payment_and_Value_of_Care-Hospital.csv :  (rows, columns) = (18728, 22)
# 2020/hospitals_archive_10_2020/Payment_and_value_of_care_Hospital.csv :  (rows, columns) = (18824, 22)
# 2020/hospitals_archive_07_2020/Payment_and_value_of_care_Hospital.csv :  (rows, columns) = (18848, 22)
# 2020/HOSArchive_Revised_Flatfiles_20200422/Payment and Value of Care - Hospital.csv :  (rows, columns) = (18896, 22)
# 2020/HOSArchive_Revised_Flatfiles_20200129/Payment and Value of Care - Hospital.csv :  (rows, columns) = (18928, 22)
# 2019/HOSArchive_Revised_Flatfiles_20191030/Payment and Value of Care - Hospital.csv :  (rows, columns) = (19028, 22)
# 2019/HOSArchive_Revised_Flatfiles_20190702/Payment and Value of Care - Hospital.csv :  (rows, columns) = (19032, 22)
# 2019/HOSArchive_Revised_FlatFiles_20190424/Payment and Value of Care - Hospital.csv :  (rows, columns) = (19088, 22)
# 2019/HOSArchive_Revised_Flatfiles_20190321/Payment and Value of Care - Hospital.csv :  (rows, columns) = (19136, 22)
# 2018/HOSArchive_Revised_FlatFiles_20181031/Payment and Value of Care - Hospital.csv :  (rows, columns) = (19172, 22)
# 2018/HOSArchive_Revised_FlatFiles_20180725/Payment and Value of Care - Hospital.csv :  (rows, columns) = (19188, 22)
# 2018/HOSArchive_Revised_FlatFiles_20180523/Payment and Value of Care - Hospital.csv :  (rows, columns) = (19192, 22)
# 2018/HOSArchive_Revised_FlatFiles_20180126/Payment and Value of Care - Hospital.csv :  (rows, columns) = (19224, 22)
# 2017/HOSArchive_Revised_FlatFiles_20171024/Payment and Value of Care - Hospital.csv :  (rows, columns) = (19248, 22)
# 2017/HOSArchive_Revised_FlatFiles_20170726/Payment and Value of Care - Hospital.csv :  (rows, columns) = (19248, 22)
# 2017/HOSArchive_Revised_Flatfiles_20170428/Payment and Value of Care - Hospital.csv :  (rows, columns) = (14415, 22)
# 2016/HOSArchive_Revised_Flatfiles_20161219/Payment and Value of Care - Hospital.csv :  (rows, columns) = (14421, 22)
# 2016/Hospital_Revised_FlatFiles_20161110/Payment and Value of Care - Hospital.csv :  (rows, columns) = (14454, 22)
# 2016/HOSArchive_Revised_FlatFiles_20160810/Payment and Value of Care - Hospital.csv :  (rows, columns) = (13878, 22)
# 2016/HOSArchive_Revised_FlatFiles_20160504/Payment and Value of Care - Hospital.csv :  (rows, columns) = (14316, 22)
# 2015/HOSArchive_Revised_FlatFiles_20151210/Payment and Value of Care - Hospital.csv :  (rows, columns) = (14301, 22)
# 2015/HOSArchive_Revised_FlatFiles_20151008/Payment and Value of Care - Hospital.csv :  (rows, columns) = (14277, 22)
# 2015/HOSArchive_Revised_FlatFiles_20150716/Payment - Hospital.csv :  (rows, columns) = (14355, 18)
# df.shape: (625121, 24)
# df.shape: (400024, 24)
#                       Address    City County Name Denominator    End Date  \
# 0      1108 ROSS CLARK CIRCLE  DOTHAN     HOUSTON         311  06/30/2021
# 1      1108 ROSS CLARK CIRCLE  DOTHAN     HOUSTON         620  06/30/2021
# 2      1108 ROSS CLARK CIRCLE  DOTHAN     HOUSTON         397  06/30/2021
# 3      1108 ROSS CLARK CIRCLE  DOTHAN     HOUSTON         101  03/31/2021
# 4  2505 U S HIGHWAY 431 NORTH    BOAZ    MARSHALL          48  06/30/2021
#
#   Facility ID                    Facility Name Higher Estimate Lower Estimate  \
# 0      010001  SOUTHEAST HEALTH MEDICAL CENTER         $29,027        $24,890
# 1      010001  SOUTHEAST HEALTH MEDICAL CENTER         $18,783        $16,947
# 2      010001  SOUTHEAST HEALTH MEDICAL CENTER         $20,653        $19,430
# 3      010001  SOUTHEAST HEALTH MEDICAL CENTER         $23,309        $20,104
# 4      010005         MARSHALL MEDICAL CENTERS         $29,475        $22,668
#
#    Payment                                Payment Category Payment Footnote  \
# 0  $26,894  No Different Than the National Average Payment              NaN
# 1  $17,835  No Different Than the National Average Payment              NaN
# 2  $20,182  No Different Than the National Average Payment              NaN
# 3  $21,623  No Different Than the National Average Payment              NaN
# 4  $25,814  No Different Than the National Average Payment              NaN
#
#   Payment Measure ID                       Payment Measure Name  \
# 0        PAYM_30_AMI          Payment for heart attack patients
# 1         PAYM_30_HF         Payment for heart failure patients
# 2         PAYM_30_PN             Payment for pneumonia patients
# 3   PAYM_90_HIP_KNEE  Payment for hip/knee replacement patients
# 4        PAYM_30_AMI          Payment for heart attack patients
#
#      Phone Number  Start Date State  \
# 0  (334) 793-8701  07/01/2018    AL
# 1  (334) 793-8701  07/01/2018    AL
# 2  (334) 793-8701  07/01/2018    AL
# 3  (334) 793-8701  04/01/2018    AL
# 4  (256) 593-8310  07/01/2018    AL
#
#                       Value of Care Category Value of Care Display ID  \
# 0      Average Mortality and Average Payment         MORT_PAYM_30_AMI
# 1       Better Mortality and Average Payment          MORT_PAYM_30_HF
# 2      Average Mortality and Average Payment          MORT_PAYM_30_PN
# 3  Average Complications and Average Payment    COMP_PAYM_90_HIP_KNEE
# 4      Average Mortality and Average Payment         MORT_PAYM_30_AMI
#
#            Value of Care Display Name Value of Care Footnote  ZIP Code  \
# 0  Value of Care Heart Attack measure                    NaN     36301
# 1  Value of Care Heart Failure measur                    NaN     36301
# 2     Value of Care Pneumonia measure                    NaN     36301
# 3  Value of Care hip/knee replacement                    NaN     36301
# 4  Value of Care Heart Attack measure                    NaN     35957
#
#   file_month file_year
# 0         01      2023
# 1         01      2023
# 2         01      2023
# 3         01      2023
# 4         01      2023

# %%
df = df.filter(items=['Facility ID', 'Facility Name', 'file_month', 'file_year', 
                      'Start Date', 'End Date', 'Denominator',
                      'Payment Measure ID', 'Payment Measure Name', 
                      'Payment Category', 'Payment Footnote', 'Payment', 
                      'Higher Estimate', 'Lower Estimate',
                      'Value of Care Category', 'Value of Care Display ID', 
                      'Value of Care Display Name', 'Value of Care Footnote',
                      ], axis=1)

d = {'No Different Than the National Average Payment': 'No different than national average payment',
     'Less Than the National Average Payment': 'Less than national average payment',
     'Greater Than the National Average Payment': 'Greater than national average payment', 
     'No Different than the National Average Payment': 'No different than national average payment',
     'Greater than the National Average Payment': 'Greater than national average payment', 
     'Less than the National Average Payment': 'Less than national average payment'}
df['Payment Category'].replace(to_replace=d, inplace=True)

d = {'Value of Care Heart Attack measure': 'Value of Care - Heart Attack',
     'Value of Care Heart Failure measur': 'Value of Care - Heart Failure',
     'Value of Care Pneumonia measure': 'Value of Care - Pneumonia',
     'Value of Care Heart Failure measure': 'Value of Care - Heart Failure',
     'Value of Care hip/knee replacement measure': 'Value of Care - hip/knee replacement',
     'Value of Care hip/knee replacement': 'Value of Care - hip/knee replacement',
     np.nan: 'Not Available'}
df['Value of Care Display Name'].replace(to_replace=d, inplace=True)

d = {'Average Mortality and Average Payment': 'Average mortality and average payment',     
     'Average Mortality and Higher Payment': 'Average mortality and higher payment',
     'Average Mortality and Lower Payment': 'Average mortality and lower payment',
     'Better Mortality and Average Payment': 'Better mortality and average payment',
     'Better Mortality and Higher Payment': 'Better mortality and higher payment',
     'Better Mortality and Lower Payment': 'Better mortality and lower payment',
     'Worse Mortality and Average Payment': 'Worse mortality and average payment', 
     'Worse Mortality and Higher Payment': 'Worse mortality and higher payment',
     'Worse Mortality and Lower Payment': 'Worse mortality and lower payment',
     'Average Complications and Average Payment':'Average complications and average payment',
     'Average Complications and Higher Payment': 'Average complications and higher payment',
     'Average Complications and Lower Payment': 'Average complications and lower payment',
     'Better Complications and Average Payment': 'Better complications and average payment',
     'Better Complications and Higher Payment': 'Better complications and higher payment',
     'Better Complications and Lower Payment': 'Better complications and lower payment',
     'Worse Complications and Average Payment': 'Worse complications and average payment',
     'Worse Complications and Higher Payment': 'Worse complications and higher payment',
     'Worse Complications and Lower Payment': 'Worse complications and lower payment',
      np.nan: 'Not Available'}
df['Value of Care Category'].replace(to_replace=d, inplace=True)
df.head()
# Out:
#   Facility ID                    Facility Name file_month file_year  \
# 0      010001  SOUTHEAST HEALTH MEDICAL CENTER         01      2023
# 1      010001  SOUTHEAST HEALTH MEDICAL CENTER         01      2023
# 2      010001  SOUTHEAST HEALTH MEDICAL CENTER         01      2023
# 3      010001  SOUTHEAST HEALTH MEDICAL CENTER         01      2023
# 4      010005         MARSHALL MEDICAL CENTERS         01      2023
#
#    Start Date    End Date Denominator Payment Measure ID  \
# 0  07/01/2018  06/30/2021         311        PAYM_30_AMI
# 1  07/01/2018  06/30/2021         620         PAYM_30_HF
# 2  07/01/2018  06/30/2021         397         PAYM_30_PN
# 3  04/01/2018  03/31/2021         101   PAYM_90_HIP_KNEE
# 4  07/01/2018  06/30/2021          48        PAYM_30_AMI
#
#                         Payment Measure Name  \
# 0          Payment for heart attack patients
# 1         Payment for heart failure patients
# 2             Payment for pneumonia patients
# 3  Payment for hip/knee replacement patients
# 4          Payment for heart attack patients
#
#                              Payment Category Payment Footnote  Payment  \
# 0  No different than national average payment              NaN  $26,894
# 1  No different than national average payment              NaN  $17,835
# 2  No different than national average payment              NaN  $20,182
# 3  No different than national average payment              NaN  $21,623
# 4  No different than national average payment              NaN  $25,814
#
#   Higher Estimate Lower Estimate                     Value of Care Category  \
# 0         $29,027        $24,890      Average mortality and average payment
# 1         $18,783        $16,947       Better mortality and average payment
# 2         $20,653        $19,430      Average mortality and average payment
# 3         $23,309        $20,104  Average complications and average payment
# 4         $29,475        $22,668      Average mortality and average payment
#
#   Value of Care Display ID            Value of Care Display Name  \
# 0         MORT_PAYM_30_AMI          Value of Care - Heart Attack
# 1          MORT_PAYM_30_HF         Value of Care - Heart Failure
# 2          MORT_PAYM_30_PN             Value of Care - Pneumonia
# 3    COMP_PAYM_90_HIP_KNEE  Value of Care - hip/knee replacement
# 4         MORT_PAYM_30_AMI          Value of Care - Heart Attack
#
#   Value of Care Footnote
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN

# %%
df['Measure Name'] = df['Payment Measure Name'] + ' (' + df['Payment Measure ID'] + ')'
df = df.filter(items=['Facility ID', 'Facility Name', 'file_month', 'file_year', 'Measure Name', 
                      'Denominator', 'Payment Category', 'Payment', 'Higher Estimate', 
                      'Lower Estimate', 'Value of Care Category', 'Start Date', 'End Date'])

labs = ['Payment', 'Higher Estimate', 'Lower Estimate']
for lab in labs:
    scores = []
    for s in df[lab].tolist():
        if s == 'Not Available':
            s = np.nan
        else:
            s = s.strip('$')
            s = s.replace(',', '')
            s = float(s)
        scores.append(s)
    df[lab] = scores

# %%
cols = ['Facility ID', 'Facility Name', 'file_month', 'file_year', 'Start Date', 'End Date']
main_df = pd.DataFrame(columns=cols)
Measures = sorted(df['Measure Name'].unique())

for i, mi in enumerate(Measures):    
    tdf = df[df['Measure Name'] == mi]
    measures = sorted(tdf['Measure Name'].unique())
    
    df2 = pd.DataFrame(columns=cols)

    for j, m in enumerate(measures):
        tdf2 = tdf[tdf['Measure Name'] == m]
        for n in list(tdf2):
            if n == 'Measure Name' or n in cols:
                continue
            else:
                tdf2[n] = pd.to_numeric(tdf2[n], errors='coerce')
                tdf2.rename(columns={n: m + ' (' + n + ')'}, inplace=True)
        
        tdf2.drop(labels=['Measure Name'], axis=1, inplace=True)
        
        df2 = df2.merge(tdf2, on=cols, how='outer')
    
    main_df = main_df.merge(df2, on=cols, how='outer')

tdf = main_df.copy(deep=True)
del df2, main_df

print(tdf.shape)
tdf = tdf.loc[:, ~tdf.T.duplicated(keep='first')]
tdf.dropna(how='all', axis=1, inplace=True)
print(tdf.shape)
tdf.drop_duplicates(inplace=True)
print(tdf.shape)
tdf.drop_duplicates(subset = cols, inplace=True)
print(tdf.shape)
tdf.head()
# Out:
# (206890, 30)
# (206890, 22)
# (206890, 22)
# (206890, 22)
#   Facility ID                    Facility Name file_month file_year  \
# 0      010001  SOUTHEAST HEALTH MEDICAL CENTER         01      2023
# 1      010005         MARSHALL MEDICAL CENTERS         01      2023
# 2      010006     NORTH ALABAMA MEDICAL CENTER         01      2023
# 3      010011               ST. VINCENT'S EAST         01      2023
# 4      010012   DEKALB REGIONAL MEDICAL CENTER         01      2023
#
#    Payment for heart attack patients (PAYM_30_AMI) (Denominator)  \
# 0                                              311.0
# 1                                               48.0
# 2                                              287.0
# 3                                              128.0
# 4                                               52.0
#
#    Payment for heart attack patients (PAYM_30_AMI) (Payment)  \
# 0                                            26894.0
# 1                                            25814.0
# 2                                            28589.0
# 3                                            29000.0
# 4                                            23731.0
#
#    Payment for heart attack patients (PAYM_30_AMI) (Higher Estimate)  \
# 0                                            29027.0
# 1                                            29475.0
# 2                                            30977.0
# 3                                            32482.0
# 4                                            27002.0
#
#    Payment for heart attack patients (PAYM_30_AMI) (Lower Estimate)  \
# 0                                            24890.0
# 1                                            22668.0
# 2                                            26395.0
# 3                                            26238.0
# 4                                            20779.0
#
#    Start Date    End Date  \
# 0  07/01/2018  06/30/2021
# 1  07/01/2018  06/30/2021
# 2  07/01/2018  06/30/2021
# 3  07/01/2018  06/30/2021
# 4  07/01/2018  06/30/2021
#
#    Payment for heart failure patients (PAYM_30_HF) (Denominator)  \
# 0                                              620.0
# 1                                              142.0
# 2                                              451.0
# 3                                              256.0
# 4                                               96.0
#
#    Payment for heart failure patients (PAYM_30_HF) (Payment)  \
# 0                                            17835.0
# 1                                            17287.0
# 2                                            18745.0
# 3                                            17700.0
# 4                                            18265.0
#
#    Payment for heart failure patients (PAYM_30_HF) (Higher Estimate)  \
# 0                                            18783.0
# 1                                            19040.0
# 2                                            19918.0
# 3                                            19110.0
# 4                                            20364.0
#
#    Payment for heart failure patients (PAYM_30_HF) (Lower Estimate)  \
# 0                                            16947.0
# 1                                            15749.0
# 2                                            17693.0
# 3                                            16428.0
# 4                                            16445.0
#
#    Payment for hip/knee replacement patients (PAYM_90_HIP_KNEE) (Denominator)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Payment for hip/knee replacement patients (PAYM_90_HIP_KNEE) (Payment)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Payment for hip/knee replacement patients (PAYM_90_HIP_KNEE) (Higher Estimate)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Payment for hip/knee replacement patients (PAYM_90_HIP_KNEE) (Lower Estimate)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Payment for pneumonia patients (PAYM_30_PN) (Denominator)  \
# 0                                              397.0
# 1                                              343.0
# 2                                              511.0
# 3                                              316.0
# 4                                              191.0
#
#    Payment for pneumonia patients (PAYM_30_PN) (Payment)  \
# 0                                            20182.0
# 1                                            18639.0
# 2                                            20218.0
# 3                                            21250.0
# 4                                            18938.0
#
#    Payment for pneumonia patients (PAYM_30_PN) (Higher Estimate)  \
# 0                                            20653.0
# 1                                            19563.0
# 2                                            20779.0
# 3                                            22079.0
# 4                                            19683.0
#
#    Payment for pneumonia patients (PAYM_30_PN) (Lower Estimate)
# 0                                            19430.0
# 1                                            18407.0
# 2                                            19452.0
# 3                                            19527.0
# 4                                            18699.0

# %%
ttdf = tdf.drop(labels=['Start Date', 'End Date'], axis=1)
ttdf.drop_duplicates(inplace=True)
print(ttdf.shape)
# Out:
# (206890, 20)

# %%
start_time = time.time()
ttdf['marker'] = ttdf['Facility ID'] + ' | ' + ttdf['Facility Name']  + ' | ' + ttdf['file_month'] + ' | ' + ttdf['file_year']
end_time = time.time()
print("Run time = {:.3f} seconds".format(end_time - start_time))
print(ttdf.shape)

start_time = time.time()
column = ttdf.pop('marker')
ttdf.insert(0, column.name, column)
end_time = time.time()
print("Run time = {:.3f} seconds".format(end_time - start_time))
print(ttdf.shape)

start_time = time.time()
ttdf.drop_duplicates(inplace=True)
end_time = time.time()
print("Run time = {:.3f} seconds".format(end_time - start_time))
print(ttdf.shape)

start_time = time.time()
collapsed_df = ttdf.groupby(ttdf.marker).apply(lambda group: group.ffill().bfill().head(1))
end_time = time.time()
print("Run time = {:.3f} seconds".format(end_time - start_time))
print(ttdf.shape)

start_time = time.time()
ttdf = collapsed_df.reset_index(drop=True)
end_time = time.time()
print("Run time = {:.3f} seconds".format(end_time - start_time))
print(ttdf.shape)

start_time = time.time()
ttdf.drop_duplicates(inplace=True)
end_time = time.time()
print("Run time = {:.3f} seconds".format(end_time - start_time))
print(ttdf.shape)

ttdf.head()
# Out:
# Run time = 0.132 seconds
# (206890, 21)
# Run time = 0.002 seconds
# (206890, 21)
# Run time = 0.288 seconds
# (206890, 21)
# Run time = 2721.584 seconds
# (206890, 21)
# Run time = 0.073 seconds
# (140392, 21)
# Run time = 0.197 seconds
# (140392, 21)
#                                               marker Facility ID  \
# 0  010001 | SOUTHEAST ALABAMA MEDICAL CENTER | 01...      010001
# 1  010001 | SOUTHEAST ALABAMA MEDICAL CENTER | 01...      010001
# 2  010001 | SOUTHEAST ALABAMA MEDICAL CENTER | 01...      010001
# 3  010001 | SOUTHEAST ALABAMA MEDICAL CENTER | 03...      010001
# 4  010001 | SOUTHEAST ALABAMA MEDICAL CENTER | 03...      010001
#
#                       Facility Name file_month file_year  \
# 0  SOUTHEAST ALABAMA MEDICAL CENTER         01      2018
# 1  SOUTHEAST ALABAMA MEDICAL CENTER         01      2020
# 2  SOUTHEAST ALABAMA MEDICAL CENTER         01      2021
# 3  SOUTHEAST ALABAMA MEDICAL CENTER         03      2019
# 4  SOUTHEAST ALABAMA MEDICAL CENTER         03      2021
#
#    Payment for heart attack patients (PAYM_30_AMI) (Denominator)  \
# 0                                              716.0
# 1                                              668.0
# 2                                              574.0
# 3                                              715.0
# 4                                              574.0
#
#    Payment for heart attack patients (PAYM_30_AMI) (Payment)  \
# 0                                            22178.0
# 1                                            24216.0
# 2                                            24934.0
# 3                                            23394.0
# 4                                            24934.0
#
#    Payment for heart attack patients (PAYM_30_AMI) (Higher Estimate)  \
# 0                                            23323.0
# 1                                            25579.0
# 2                                            26429.0
# 3                                            24641.0
# 4                                            26429.0
#
#    Payment for heart attack patients (PAYM_30_AMI) (Lower Estimate)  \
# 0                                            21108.0
# 1                                            22939.0
# 2                                            23490.0
# 3                                            22216.0
# 4                                            23490.0
#
#    Payment for heart failure patients (PAYM_30_HF) (Denominator)  \
# 0                                              824.0
# 1                                              828.0
# 2                                              823.0
# 3                                              813.0
# 4                                              823.0
#
#    Payment for heart failure patients (PAYM_30_HF) (Payment)  \
# 0                                            16525.0
# 1                                            17716.0
# 2                                            17854.0
# 3                                            17041.0
# 4                                            17854.0
#
#    Payment for heart failure patients (PAYM_30_HF) (Higher Estimate)  \
# 0                                            17335.0
# 1                                            18523.0
# 2                                            18676.0
# 3                                            17849.0
# 4                                            18676.0
#
#    Payment for heart failure patients (PAYM_30_HF) (Lower Estimate)  \
# 0                                            15754.0
# 1                                            16905.0
# 2                                            17061.0
# 3                                            16268.0
# 4                                            17061.0
#
#    Payment for hip/knee replacement patients (PAYM_90_HIP_KNEE) (Denominator)  \
# 0                                              335.0
# 1                                              284.0
# 2                                              245.0
# 3                                              310.0
# 4                                              245.0
#
#    Payment for hip/knee replacement patients (PAYM_90_HIP_KNEE) (Payment)  \
# 0                                            26863.0
# 1                                            24984.0
# 2                                            22216.0
# 3                                            25812.0
# 4                                            22216.0
#
#    Payment for hip/knee replacement patients (PAYM_90_HIP_KNEE) (Higher Estimate)  \
# 0                                            28041.0
# 1                                            26172.0
# 2                                            23313.0
# 3                                            26982.0
# 4                                            23313.0
#
#    Payment for hip/knee replacement patients (PAYM_90_HIP_KNEE) (Lower Estimate)  \
# 0                                            25762.0
# 1                                            23894.0
# 2                                            21191.0
# 3                                            24704.0
# 4                                            21191.0
#
#    Payment for pneumonia patients (PAYM_30_PN) (Denominator)  \
# 0                                              573.0
# 1                                              531.0
# 2                                              536.0
# 3                                              534.0
# 4                                              536.0
#
#    Payment for pneumonia patients (PAYM_30_PN) (Payment)  \
# 0                                            17230.0
# 1                                            19203.0
# 2                                            20216.0
# 3                                            18281.0
# 4                                            20216.0
#
#    Payment for pneumonia patients (PAYM_30_PN) (Higher Estimate)  \
# 0                                            18106.0
# 1                                            20214.0
# 2                                            21271.0
# 3                                            19236.0
# 4                                            21271.0
#
#    Payment for pneumonia patients (PAYM_30_PN) (Lower Estimate)
# 0                                            16358.0
# 1                                            18191.0
# 2                                            19186.0
# 3                                            17354.0
# 4                                            19186.0

# %% [markdown]
# ## Save dataframe

# %%
ttdf.drop(labels=['marker'], axis=1, inplace=True)
ttdf.to_pickle('~/GitHub/hospitals-data-archive/dataframes/partial_dataframes/Payment_and_ValueOfCare_df.pkl.gz', protocol=5, compression='gzip')

# %%
m1 = list(ttdf)
ls = ['Facility ID','Facility Name','file_month','file_year']
for l in ls: 
    m1.remove(l)

# %% [markdown]
# ## Save measurement dates

# %%
# Columns to keep as is
id_cols = ['Facility ID', 'Facility Name', 'file_month', 'file_year', 'Start Date', 'End Date']

# Melt the specific columns and create the 'Measure' and 'Score' columns
measures_df = df.melt(id_vars=id_cols, var_name='Measure Name', value_name='Score')
measures_df.drop(labels=['Score', 'Facility ID', 'Facility Name'], axis=1, inplace=True)

print(measures_df.shape)
measures_df.drop_duplicates(inplace=True)
measures_df.reset_index(drop=True, inplace=True)
print(measures_df.shape)

measures_df['Start Date'] = pd.to_datetime(measures_df['Start Date'])
measures_df['End Date'] = pd.to_datetime(measures_df['End Date'])
measures_df.to_csv('~/GitHub/hospitals-data-archive/measure_dates/Payment_and_ValueOfCare_df.csv')

measures_df.head()
# Out:
# (2800168, 5)
# (434, 5)
#   file_month file_year Start Date   End Date  Measure Name
# 0         01      2023 2018-07-01 2021-06-30  Measure Name
# 1         01      2023 2018-04-01 2021-03-31  Measure Name
# 2         04      2023 2018-07-01 2021-06-30  Measure Name
# 3         04      2023 2018-04-01 2021-03-31  Measure Name
# 4         07      2023 2019-07-01 2022-06-30  Measure Name

# %%
m2 = measures_df['Measure Name'].unique().tolist()
sorted(m1) == sorted(m2)
# Out:
# False

# %%
print(sorted(m1))
print('\n')
print(sorted(m2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <module>
# ----> 1 print(sorted(m1))
#       2 print('\n')
#       3 print(sorted(m2))
#
# NameError: name 'm1' is not defined
