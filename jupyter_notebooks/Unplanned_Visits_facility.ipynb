# %% [markdown]
# # Generate Unplanned Visits dataframe

# %%
import pandas as pd
import numpy as np
import warnings
from IPython.utils import io
import sys
import time

warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

main_dir = '~/Desktop/Rush/CMS_HospitalArchives/'

# %% [markdown]
# ## Define Custom Functions

# %%
def curate(df):
    try:
        df = df[df['Facility ID'] != np.nan]
        df['Facility ID'] = df['Facility ID'].values.astype(str)
        
        ids = df['Facility ID'].tolist()
        ids2 = []
        for i in ids:
            if len(i) < 6:
                i = '0' + i
            ids2.append(i)
        df['Facility ID'] = ids2
        
    except:
        pass
    try:
        df = df[df['Facility Name'] != np.nan]
    except:
        pass
    
    for c in list(df):    
        try:
            df[c] = df[c].str.replace("\t","")
        except:
            pass

    return df


def rename_and_fill(df):
    
    cols1 = ['Provider ID', "Measure Start Date", "Measure End Date",
             'Hospital Name', 'Address 1', 'City/Town', 'County/Parish',
             'Telephone Number',
             ]
    
    
    cols2 = ['Facility ID', "Start Date", "End Date",
             'Facility Name', 'Address', 'City', 'County Name',
             'Phone Number',
             ]
    
    for i, col in enumerate(cols1):
        if col in list(df):
            df.rename(columns={col: cols2[i]}, inplace=True)
            
            
    cols = ['Number of Patients', 'Number of Patients Returned',
            ]
    
    for col in cols:
        if col not in list(df):
            df[col] = float('NaN')
    
    l = list(df)
    l = list(set([x for x in l if l.count(x) > 1]))
    if len(l) > 0:
        print('duplicates:', l)
        sys.exit()
        
    return df


def process2(df, lists, yr, mo):
    df = rename_and_fill(df)
    df = curate(df)
    lists.append(list(df))
    df['file_month'] = [mo]* df.shape[0]
    df['file_year'] = [yr]* df.shape[0]
    df = df.reindex(sorted(df.columns), axis=1)
    return df, lists

# %% [markdown]
# ## Load Files

# %%
df_list = []
lists = []

yrs = ['2023', '2023', '2023', '2023',
       '2022', '2022', '2022', '2022',
       '2021','2021','2021', '2021', '2021',
       '2020', '2020', '2020', '2020', 
       '2019', '2019', '2019', '2019', 
       '2018', '2018', '2018', '2018',
       ]

mos = ['01', '04', '07', '10',
       '01', '04', '07', '10',
       '01', '03', '04', '07', '10', 
       '10', '07', '04', '01', 
       '10', '07', '04', '03', 
       '10', '07', '05', '01',
       ]

subdirs = ['2023/hospitals_01_2023/Unplanned_Hospital_Visits-Hospital.csv', 
           '2023/hospitals_04_2023/Unplanned_Hospital_Visits-Hospital.csv',
           '2023/hospitals_07_2023/Unplanned_Hospital_Visits-Hospital.csv',
           '2023/hospitals_10_2023/Unplanned_Hospital_Visits-Hospital.csv',
           
           '2022/hospitals_01_2022/Unplanned_Hospital_Visits-Hospital.csv', 
           '2022/hospitals_04_2022/Unplanned_Hospital_Visits-Hospital.csv',
           '2022/hospitals_07_2022/Unplanned_Hospital_Visits-Hospital.csv',
           '2022/hospitals_10_2022/Unplanned_Hospital_Visits-Hospital.csv',
           
           '2021/hospitals_01_2021/Unplanned_Hospital_Visits-Hospital.csv',
           '2021/hospitals_03_2021/Unplanned_Hospital_Visits-Hospital.csv',
           '2021/hospitals_04_2021/Unplanned_Hospital_Visits-Hospital.csv',
           '2021/hospitals_07_2021/Unplanned_Hospital_Visits-Hospital.csv',
           '2021/hospitals_10_2021/Unplanned_Hospital_Visits-Hospital.csv',
           
           '2020/hospitals_archive_10_2020/Unplanned_Hospital_Visits_Hospital.csv',
           '2020/hospitals_archive_07_2020/Unplanned_Hospital_Visits_Hospital.csv',
           '2020/HOSArchive_Revised_Flatfiles_20200422/Unplanned Hospital Visits - Hospital.csv',
           '2020/HOSArchive_Revised_Flatfiles_20200129/Unplanned Hospital Visits - Hospital.csv',
           
           '2019/HOSArchive_Revised_Flatfiles_20191030/Unplanned Hospital Visits - Hospital.csv',
           '2019/HOSArchive_Revised_Flatfiles_20190702/Unplanned Hospital Visits - Hospital.csv',
           '2019/HOSArchive_Revised_FlatFiles_20190424/Unplanned Hospital Visits - Hospital.csv',
           '2019/HOSArchive_Revised_Flatfiles_20190321/Unplanned Hospital Visits - Hospital.csv',
           
           '2018/HOSArchive_Revised_FlatFiles_20181031/Unplanned Hospital Visits - Hospital.csv',
           '2018/HOSArchive_Revised_FlatFiles_20180725/Unplanned Hospital Visits - Hospital.csv', 
           '2018/HOSArchive_Revised_FlatFiles_20180523/Unplanned Hospital Visits - Hospital.csv',
           '2018/HOSArchive_Revised_FlatFiles_20180126/Unplanned Hospital Visits - Hospital.csv',
           
           ]

for i, subdir in enumerate(subdirs):
    with io.capture_output() as captured: df = pd.read_csv(main_dir + subdir, encoding = "ISO-8859-1")
    print(subdir + ' :  (rows, columns) =', df.shape)
    df, lists = process2(df, lists, yrs[i], mos[i])
    df_list.append(df)

subdir = 'Unplanned_Visits/CombinedFiles_Unplanned_Visits'
df = pd.concat(df_list)

print('df.shape:', df.shape)
df = df[~df['Score'].isin([np.nan, float("NaN"), 'Not Available'])]
print('df.shape:', df.shape)

print(sorted(list(df)))

df['End Date'] = pd.to_datetime(df['End Date'])
df['Start Date'] = pd.to_datetime(df['Start Date'])

print(df['Measure ID'].unique(), '\n')
print(df['Measure Name'].unique(), '\n')

df.head()
# Out:
# 2023/hospitals_01_2023/Unplanned_Hospital_Visits-Hospital.csv :  (rows, columns) = (67872, 20)
# 2023/hospitals_04_2023/Unplanned_Hospital_Visits-Hospital.csv :  (rows, columns) = (67830, 20)
# 2023/hospitals_07_2023/Unplanned_Hospital_Visits-Hospital.csv :  (rows, columns) = (67732, 20)
# 2023/hospitals_10_2023/Unplanned_Hospital_Visits-Hospital.csv :  (rows, columns) = (67732, 20)
# 2022/hospitals_01_2022/Unplanned_Hospital_Visits-Hospital.csv :  (rows, columns) = (67872, 20)
# 2022/hospitals_04_2022/Unplanned_Hospital_Visits-Hospital.csv :  (rows, columns) = (67872, 20)
# 2022/hospitals_07_2022/Unplanned_Hospital_Visits-Hospital.csv :  (rows, columns) = (67802, 20)
# 2022/hospitals_10_2022/Unplanned_Hospital_Visits-Hospital.csv :  (rows, columns) = (67830, 20)
# 2021/hospitals_01_2021/Unplanned_Hospital_Visits-Hospital.csv :  (rows, columns) = (68348, 20)
# 2021/hospitals_03_2021/Unplanned_Hospital_Visits-Hospital.csv :  (rows, columns) = (68348, 20)
# 2021/hospitals_04_2021/Unplanned_Hospital_Visits-Hospital.csv :  (rows, columns) = (68768, 20)
# 2021/hospitals_07_2021/Unplanned_Hospital_Visits-Hospital.csv :  (rows, columns) = (68124, 20)
# 2021/hospitals_10_2021/Unplanned_Hospital_Visits-Hospital.csv :  (rows, columns) = (67970, 20)
# 2020/hospitals_archive_10_2020/Unplanned_Hospital_Visits_Hospital.csv :  (rows, columns) = (68292, 20)
# 2020/hospitals_archive_07_2020/Unplanned_Hospital_Visits_Hospital.csv :  (rows, columns) = (68376, 20)
# 2020/HOSArchive_Revised_Flatfiles_20200422/Unplanned Hospital Visits - Hospital.csv :  (rows, columns) = (68407, 20)
# 2020/HOSArchive_Revised_Flatfiles_20200129/Unplanned Hospital Visits - Hospital.csv :  (rows, columns) = (68519, 18)
# 2019/HOSArchive_Revised_Flatfiles_20191030/Unplanned Hospital Visits - Hospital.csv :  (rows, columns) = (54082, 18)
# 2019/HOSArchive_Revised_Flatfiles_20190702/Unplanned Hospital Visits - Hospital.csv :  (rows, columns) = (54093, 18)
# 2019/HOSArchive_Revised_FlatFiles_20190424/Unplanned Hospital Visits - Hospital.csv :  (rows, columns) = (59191, 18)
# 2019/HOSArchive_Revised_Flatfiles_20190321/Unplanned Hospital Visits - Hospital.csv :  (rows, columns) = (59335, 18)
# 2018/HOSArchive_Revised_FlatFiles_20181031/Unplanned Hospital Visits - Hospital.csv :  (rows, columns) = (57924, 18)
# 2018/HOSArchive_Revised_FlatFiles_20180725/Unplanned Hospital Visits - Hospital.csv :  (rows, columns) = (57564, 20)
# 2018/HOSArchive_Revised_FlatFiles_20180523/Unplanned Hospital Visits - Hospital.csv :  (rows, columns) = (52778, 18)
# 2018/HOSArchive_Revised_FlatFiles_20180126/Unplanned Hospital Visits - Hospital.csv :  (rows, columns) = (52866, 18)
# df.shape: (1605527, 22)
# df.shape: (930286, 22)
# ['Address', 'City', 'Compared to National', 'County Name', 'Denominator', 'End Date', 'Facility ID', 'Facility Name', 'Footnote', 'Higher Estimate', 'Lower Estimate', 'Measure ID', 'Measure Name', 'Number of Patients', 'Number of Patients Returned', 'Phone Number', 'Score', 'Start Date', 'State', 'ZIP Code', 'file_month', 'file_year']
# ['EDAC_30_AMI' 'EDAC_30_HF' 'EDAC_30_PN' 'OP_32' 'OP_35_ADM' 'OP_35_ED'
#  'OP_36' 'READM_30_AMI' 'READM_30_CABG' 'READM_30_COPD' 'READM_30_HF'
#  'READM_30_HIP_KNEE' 'READM_30_HOSP_WIDE' 'READM_30_PN' 'READM_30_STK'
#  'OP-32']
#
# ['Hospital return days for heart attack patients'
#  'Hospital return days for heart failure patients'
#  'Hospital return days for pneumonia patients'
#  'Rate of unplanned hospital visits after colonoscopy (per 1,000 colonoscopies)'
#  'Rate of inpatient admissions for patients receiving outpatient chemotherapy'
#  'Rate of emergency department (ED) visits for patients receiving outpatient chemotherapy'
#  'Ratio of unplanned hospital visits after hospital outpatient surgery'
#  'Acute Myocardial Infarction (AMI) 30-Day Readmission Rate'
#  'Rate of readmission for CABG'
#  'Rate of readmission for chronic obstructive pulmonary disease (COPD) patients'
#  'Heart failure (HF) 30-Day Readmission Rate'
#  'Rate of readmission after hip/knee replacement'
#  'Rate of readmission after discharge from hospital (hospital-wide)'
#  'Pneumonia (PN) 30-Day Readmission Rate'
#  'Rate of readmission for stroke patients'
#  '30-Day Hospital-Wide All-Cause Unplanned Readmission Rate'
#  'Rate of readmission for heart attack patients'
#  'Rate of readmission for CABG surgery patients'
#  'Rate of readmission for heart failure patients'
#  'Rate of readmission for pneumonia patients']
#                   Address    City                       Compared to National  \
# 0  1108 ROSS CLARK CIRCLE  DOTHAN            Average Days per 100 Discharges
# 1  1108 ROSS CLARK CIRCLE  DOTHAN  More Days Than Average per 100 Discharges
# 2  1108 ROSS CLARK CIRCLE  DOTHAN            Average Days per 100 Discharges
# 3  1108 ROSS CLARK CIRCLE  DOTHAN        No Different Than the National Rate
# 4  1108 ROSS CLARK CIRCLE  DOTHAN        No Different Than the National Rate
#
#   County Name Denominator   End Date Facility ID  \
# 0     HOUSTON         319 2021-06-30      010001
# 1     HOUSTON         755 2021-06-30      010001
# 2     HOUSTON         436 2021-06-30      010001
# 3     HOUSTON         254 2021-12-31      010001
# 4     HOUSTON         214 2021-12-31      010001
#
#                      Facility Name Footnote Higher Estimate Lower Estimate  \
# 0  SOUTHEAST HEALTH MEDICAL CENTER      NaN            19.6          -13.2
# 1  SOUTHEAST HEALTH MEDICAL CENTER      NaN            39.6            4.8
# 2  SOUTHEAST HEALTH MEDICAL CENTER      NaN            16.7          -17.3
# 3  SOUTHEAST HEALTH MEDICAL CENTER      NaN            19.6           10.1
# 4  SOUTHEAST HEALTH MEDICAL CENTER      NaN            13.2            7.7
#
#     Measure ID                                       Measure Name  \
# 0  EDAC_30_AMI     Hospital return days for heart attack patients
# 1   EDAC_30_HF    Hospital return days for heart failure patients
# 2   EDAC_30_PN        Hospital return days for pneumonia patients
# 3        OP_32  Rate of unplanned hospital visits after colono...
# 4    OP_35_ADM  Rate of inpatient admissions for patients rece...
#
#   Number of Patients Number of Patients Returned    Phone Number Score  \
# 0                305                          81  (334) 793-8701   1.9
# 1                618                         211  (334) 793-8701  21.8
# 2                412                          99  (334) 793-8701  -1.5
# 3     Not Applicable              Not Applicable  (334) 793-8701  14.1
# 4     Not Applicable              Not Applicable  (334) 793-8701  10.2
#
#   Start Date State  ZIP Code file_month file_year
# 0 2018-07-01    AL     36301         01      2023
# 1 2018-07-01    AL     36301         01      2023
# 2 2018-07-01    AL     36301         01      2023
# 3 2019-01-01    AL     36301         01      2023
# 4 2021-01-01    AL     36301         01      2023

# %%
d = {
    'EDAC_30_AMI': 'EDAC-30 AMI', 
    'EDAC_30_HF': 'EDAC-30 HF',
    'EDAC_30_PN': 'EDAC-30 PN',
    'OP_32': 'OP-32',
    'OP_35_ADM': 'OP-35 ADM', 
    'OP_35_ED': 'OP-35 ED', 
    'OP_36': 'OP-36', 
    'READM_30_AMI': 'READM-30 AMI', 
    'READM_30_CABG': 'READM-30 CABG',
    'READM_30_COPD': 'READM-30 COPD', 
    'READM_30_HF': 'READM-30 HF', 
    'READM_30_HIP_KNEE': 'READM-30 HIP-KNEE', 
    'READM_30_HOSP_WIDE': 'READM-30 HOSP-WIDE', 
    'READM_30_PN': 'READM-30 PN', 
    'READM_30_STK': 'READM-30 STK',
}

df['Measure ID'].replace(to_replace=d, inplace=True)
print(len(df['Measure ID'].unique()))
print(df['Measure ID'].unique())


d = {
    'Hospital return days for heart attack patients': 'Hospital return days for AMI patients', 
    'Hospital return days for heart failure patients': 'Hospital return days for HF patients',
    'Hospital return days for pneumonia patients': 'Hospital return days for PN patients', 
    'Rate of unplanned hospital visits after colonoscopy (per 1,000 colonoscopies)': 'Rate of unplanned visits after colonoscopy (per 1K)', 
    'Rate of unplanned hospital visits after colonoscopy (per 1,000 colonoscopies)': 'Rate of unplanned visits after colonoscopy (per 1K)',
    
    'Rate of inpatient admissions for patients receiving outpatient chemotherapy': 'Inpatient admit rate for patients receiving outpatient chemo', 
    'Rate of emergency department (ED) visits for patients receiving outpatient chemotherapy': 'ED visit rate for patients receiving outpatient chemo', 
    'Ratio of unplanned hospital visits after hospital outpatient surgery': 'Ratio of unplanned visits after outpatient surgery', 
    'Acute Myocardial Infarction (AMI) 30-Day Readmission Rate': 'AMI 30-Day Readmission Rate', 
    'Rate of readmission for heart attack patients': 'AMI 30-Day Readmission Rate',
    'Rate of readmission for CABG': 'CABG 30-Day Readmission Rate',
    'Rate of readmission for CABG surgery patients': 'CABG 30-Day Readmission Rate',
    
    'Rate of readmission for chronic obstructive pulmonary disease (COPD) patients': '30-Day Readmission Rate', 
    
    'Heart failure (HF) 30-Day Readmission Rate': '30-Day HF Readmission Rate', 
    'Rate of readmission for heart failure patients': '30-Day HF Readmission Rate',
    
    'Rate of readmission after hip/knee replacement': '30-Day Readmission Rate after hip/knee replacement', 
    
    '30-Day Hospital-Wide All-Cause Unplanned Readmission Rate': '30-Day Hospital-Wide All-Cause Unplanned Readmission Rate', 
    'Rate of readmission after discharge from hospital (hospital-wide)': '30-Day Hospital-Wide All-Cause Unplanned Readmission Rate',
    
    'Pneumonia (PN) 30-Day Readmission Rate': '30-Day Pneumonia Readmission Rate', 
    'Rate of readmission for pneumonia patients': '30-Day Pneumonia Readmission Rate',
    
    'Rate of readmission for stroke patients': '30-Day Readmission Rate for stroke patients',
}


df['Measure Name'].replace(to_replace=d, inplace=True)
print(len(df['Measure Name'].unique()))
print(df['Measure Name'].unique())


ls = ['Facility ID', 'Facility Name',
      'file_month', 'file_year',
      'Measure ID', 'Measure Name',
      'Start Date', 'End Date', 
      'Denominator', 'Score',
      'Higher Estimate', 'Lower Estimate',
      'Number of Patients', 'Number of Patients Returned',
      'Compared to National', 
      'Footnote', 'Address', 'City',  
      'County Name', 'Phone Number', 
      'State', 'ZIP Code',
     ]

df = df.filter(items=ls)
print(df.shape)
# Out:
# 15
# ['EDAC-30 AMI' 'EDAC-30 HF' 'EDAC-30 PN' 'OP-32' 'OP-35 ADM' 'OP-35 ED'
#  'OP-36' 'READM-30 AMI' 'READM-30 CABG' 'READM-30 COPD' 'READM-30 HF'
#  'READM-30 HIP-KNEE' 'READM-30 HOSP-WIDE' 'READM-30 PN' 'READM-30 STK']
# 15
# ['Hospital return days for AMI patients'
#  'Hospital return days for HF patients'
#  'Hospital return days for PN patients'
#  'Rate of unplanned visits after colonoscopy (per 1K)'
#  'Inpatient admit rate for patients receiving outpatient chemo'
#  'ED visit rate for patients receiving outpatient chemo'
#  'Ratio of unplanned visits after outpatient surgery'
#  'AMI 30-Day Readmission Rate' 'CABG 30-Day Readmission Rate'
#  '30-Day Readmission Rate' '30-Day HF Readmission Rate'
#  '30-Day Readmission Rate after hip/knee replacement'
#  '30-Day Hospital-Wide All-Cause Unplanned Readmission Rate'
#  '30-Day Pneumonia Readmission Rate'
#  '30-Day Readmission Rate for stroke patients']
# (930286, 22)

# %%
df['Measure Name'] = df['Measure Name'] + ' (' + df['Measure ID'] + ')'

tdf = df.filter(items=['Measure Name'])
tdf.drop_duplicates(inplace=True)

print(tdf.shape)
print(len(df['Measure Name'].unique()), 'Measure Name, ID')

tdf.sort_values(by=['Measure Name'], ascending=True, inplace=True)
tdf.head(100)
# Out:
# (15, 1)
# 15 Measure Name, ID
#                                          Measure Name
# 10           30-Day HF Readmission Rate (READM-30 HF)
# 12  30-Day Hospital-Wide All-Cause Unplanned Readm...
# 13    30-Day Pneumonia Readmission Rate (READM-30 PN)
# 9             30-Day Readmission Rate (READM-30 COPD)
# 11  30-Day Readmission Rate after hip/knee replace...
# 11  30-Day Readmission Rate for stroke patients (R...
# 7          AMI 30-Day Readmission Rate (READM-30 AMI)
# 8        CABG 30-Day Readmission Rate (READM-30 CABG)
# 5   ED visit rate for patients receiving outpatien...
# 0   Hospital return days for AMI patients (EDAC-30...
# 1   Hospital return days for HF patients (EDAC-30 HF)
# 2   Hospital return days for PN patients (EDAC-30 PN)
# 4   Inpatient admit rate for patients receiving ou...
# 3   Rate of unplanned visits after colonoscopy (pe...
# 6   Ratio of unplanned visits after outpatient sur...

# %%
df = df.filter(items=['Facility ID', 'Facility Name',
                      'file_month', 'file_year',
                      'Measure Name',
                      'Denominator', 'Score',
                      'Higher Estimate', 'Lower Estimate',
                      'Number of Patients', 'Number of Patients Returned',
                      'Start Date', 'End Date'], axis=1)

# %%
cols = ['Facility ID', 'Facility Name', 'file_month', 'file_year', 'Start Date', 'End Date']
main_df = pd.DataFrame(columns=cols)
Measures = sorted(df['Measure Name'].unique())

for i, mi in enumerate(Measures):    
    tdf = df[df['Measure Name'] == mi]
    measures = sorted(tdf['Measure Name'].unique())
    
    df2 = pd.DataFrame(columns=cols)

    for j, m in enumerate(measures):
        tdf2 = tdf[tdf['Measure Name'] == m]
        for n in list(tdf2):
            if n == 'Measure Name' or n in cols:
                continue
            else:
                tdf2[n] = pd.to_numeric(tdf2[n], errors='coerce')
                tdf2.rename(columns={n: m + ' (' + n + ')'}, inplace=True)
        
        tdf2.drop(labels=['Measure Name'], axis=1, inplace=True)
        
        df2 = df2.merge(tdf2, on=cols, how='outer')
    
    main_df = main_df.merge(df2, on=cols, how='outer')

tdf = main_df.copy(deep=True)
del df2, main_df

print(tdf.shape)
tdf = tdf.loc[:, ~tdf.T.duplicated(keep='first')]
tdf.dropna(how='all', axis=1, inplace=True)
print(tdf.shape)
tdf.drop_duplicates(inplace=True)
print(tdf.shape)
tdf.drop_duplicates(subset = cols, inplace=True)
print(tdf.shape)
tdf.head()
# Out:
# (346283, 96)
# (346283, 71)
# (346283, 71)
# (346283, 71)
#   Facility ID                    Facility Name file_month file_year  \
# 0      010001  SOUTHEAST HEALTH MEDICAL CENTER         01      2023
# 1      010005         MARSHALL MEDICAL CENTERS         01      2023
# 2      010006     NORTH ALABAMA MEDICAL CENTER         01      2023
# 3      010007         MIZELL MEMORIAL HOSPITAL         01      2023
# 4      010011               ST. VINCENT'S EAST         01      2023
#
#    30-Day HF Readmission Rate (READM-30 HF) (Denominator)  \
# 0                                              755.0
# 1                                              157.0
# 2                                              550.0
# 3                                               51.0
# 4                                              298.0
#
#    30-Day HF Readmission Rate (READM-30 HF) (Score)  \
# 0                                              22.4
# 1                                              21.4
# 2                                              20.0
# 3                                              23.7
# 4                                              19.2
#
#    30-Day HF Readmission Rate (READM-30 HF) (Higher Estimate)  \
# 0                                               25.0
# 1                                               25.4
# 2                                               22.7
# 3                                               28.3
# 4                                               22.5
#
#    30-Day HF Readmission Rate (READM-30 HF) (Lower Estimate) Start Date  \
# 0                                               20.1         2018-07-01
# 1                                               17.8         2018-07-01
# 2                                               17.5         2018-07-01
# 3                                               19.1         2018-07-01
# 4                                               16.3         2018-07-01
#
#     End Date  \
# 0 2021-06-30
# 1 2021-06-30
# 2 2021-06-30
# 3 2021-06-30
# 4 2021-06-30
#
#    30-Day Hospital-Wide All-Cause Unplanned Readmission Rate (READM-30 HOSP-WIDE) (Denominator)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    30-Day Hospital-Wide All-Cause Unplanned Readmission Rate (READM-30 HOSP-WIDE) (Score)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    30-Day Hospital-Wide All-Cause Unplanned Readmission Rate (READM-30 HOSP-WIDE) (Higher Estimate)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    30-Day Hospital-Wide All-Cause Unplanned Readmission Rate (READM-30 HOSP-WIDE) (Lower Estimate)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    30-Day Pneumonia Readmission Rate (READM-30 PN) (Denominator)  \
# 0                                              436.0
# 1                                              361.0
# 2                                              538.0
# 3                                               99.0
# 4                                              346.0
#
#    30-Day Pneumonia Readmission Rate (READM-30 PN) (Score)  \
# 0                                               16.4
# 1                                               16.7
# 2                                               19.5
# 3                                               16.4
# 4                                               17.5
#
#    30-Day Pneumonia Readmission Rate (READM-30 PN) (Higher Estimate)  \
# 0                                               18.9
# 1                                               19.5
# 2                                               22.2
# 3                                               19.8
# 4                                               20.4
#
#    30-Day Pneumonia Readmission Rate (READM-30 PN) (Lower Estimate)  \
# 0                                               14.2
# 1                                               14.3
# 2                                               17.2
# 3                                               13.2
# 4                                               15.0
#
#    30-Day Readmission Rate (READM-30 COPD) (Denominator)  \
# 0                                              202.0
# 1                                              234.0
# 2                                              235.0
# 3                                               72.0
# 4                                              101.0
#
#    30-Day Readmission Rate (READM-30 COPD) (Score)  \
# 0                                             19.9
# 1                                             17.6
# 2                                             17.7
# 3                                             19.7
# 4                                             20.6
#
#    30-Day Readmission Rate (READM-30 COPD) (Higher Estimate)  \
# 0                                               23.5
# 1                                               21.1
# 2                                               21.0
# 3                                               23.8
# 4                                               24.7
#
#    30-Day Readmission Rate (READM-30 COPD) (Lower Estimate)  \
# 0                                               16.8
# 1                                               14.8
# 2                                               14.9
# 3                                               15.7
# 4                                               17.0
#
#    30-Day Readmission Rate after hip/knee replacement (READM-30 HIP-KNEE) (Denominator)  \
# 0                                               98.0
# 1                                              178.0
# 2                                              246.0
# 3                                                NaN
# 4                                               36.0
#
#    30-Day Readmission Rate after hip/knee replacement (READM-30 HIP-KNEE) (Score)  \
# 0                                                4.2
# 1                                                4.0
# 2                                                4.8
# 3                                                NaN
# 4                                                4.2
#
#    30-Day Readmission Rate after hip/knee replacement (READM-30 HIP-KNEE) (Higher Estimate)  \
# 0                                                6.1
# 1                                                5.8
# 2                                                6.7
# 3                                                NaN
# 4                                                6.4
#
#    30-Day Readmission Rate after hip/knee replacement (READM-30 HIP-KNEE) (Lower Estimate)  \
# 0                                                2.8
# 1                                                2.7
# 2                                                3.4
# 3                                                NaN
# 4                                                2.7
#
#    30-Day Readmission Rate for stroke patients (READM-30 STK) (Denominator)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    30-Day Readmission Rate for stroke patients (READM-30 STK) (Score)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    30-Day Readmission Rate for stroke patients (READM-30 STK) (Higher Estimate)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    30-Day Readmission Rate for stroke patients (READM-30 STK) (Lower Estimate)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    AMI 30-Day Readmission Rate (READM-30 AMI) (Denominator)  \
# 0                                              319.0
# 1                                               38.0
# 2                                              312.0
# 3                                                NaN
# 4                                              139.0
#
#    AMI 30-Day Readmission Rate (READM-30 AMI) (Score)  \
# 0                                               14.9
# 1                                               14.4
# 2                                               16.5
# 3                                                NaN
# 4                                               16.0
#
#    AMI 30-Day Readmission Rate (READM-30 AMI) (Higher Estimate)  \
# 0                                               17.7
# 1                                               17.8
# 2                                               19.7
# 3                                                NaN
# 4                                               19.7
#
#    AMI 30-Day Readmission Rate (READM-30 AMI) (Lower Estimate)  \
# 0                                               12.5
# 1                                               11.4
# 2                                               13.8
# 3                                                NaN
# 4                                               13.0
#
#    CABG 30-Day Readmission Rate (READM-30 CABG) (Denominator)  \
# 0                                              165.0
# 1                                                NaN
# 2                                              109.0
# 3                                                NaN
# 4                                               61.0
#
#    CABG 30-Day Readmission Rate (READM-30 CABG) (Score)  \
# 0                                               11.7
# 1                                                NaN
# 2                                               15.6
# 3                                                NaN
# 4                                               13.8
#
#    CABG 30-Day Readmission Rate (READM-30 CABG) (Higher Estimate)  \
# 0                                               15.4
# 1                                                NaN
# 2                                               20.6
# 3                                                NaN
# 4                                               18.4
#
#    CABG 30-Day Readmission Rate (READM-30 CABG) (Lower Estimate)  \
# 0                                                8.8
# 1                                                NaN
# 2                                               11.6
# 3                                                NaN
# 4                                               10.1
#
#    ED visit rate for patients receiving outpatient chemo (OP-35 ED) (Denominator)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ED visit rate for patients receiving outpatient chemo (OP-35 ED) (Score)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ED visit rate for patients receiving outpatient chemo (OP-35 ED) (Higher Estimate)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ED visit rate for patients receiving outpatient chemo (OP-35 ED) (Lower Estimate)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Hospital return days for AMI patients (EDAC-30 AMI) (Denominator)  \
# 0                                              319.0
# 1                                               38.0
# 2                                              312.0
# 3                                                NaN
# 4                                              139.0
#
#    Hospital return days for AMI patients (EDAC-30 AMI) (Score)  \
# 0                                                1.9
# 1                                                4.7
# 2                                               25.9
# 3                                                NaN
# 4                                               13.0
#
#    Hospital return days for AMI patients (EDAC-30 AMI) (Higher Estimate)  \
# 0                                               19.6
# 1                                               49.5
# 2                                               45.1
# 3                                                NaN
# 4                                               36.7
#
#    Hospital return days for AMI patients (EDAC-30 AMI) (Lower Estimate)  \
# 0                                              -13.2
# 1                                              -28.7
# 2                                                8.4
# 3                                                NaN
# 4                                               -5.3
#
#    Hospital return days for AMI patients (EDAC-30 AMI) (Number of Patients)  \
# 0                                              305.0
# 1                                               38.0
# 2                                              301.0
# 3                                                NaN
# 4                                              134.0
#
#    Hospital return days for AMI patients (EDAC-30 AMI) (Number of Patients Returned)  \
# 0                                               81.0
# 1                                                9.0
# 2                                               80.0
# 3                                                NaN
# 4                                               40.0
#
#    Hospital return days for HF patients (EDAC-30 HF) (Denominator)  \
# 0                                              755.0
# 1                                              157.0
# 2                                              550.0
# 3                                               51.0
# 4                                              298.0
#
#    Hospital return days for HF patients (EDAC-30 HF) (Score)  \
# 0                                               21.8
# 1                                                9.3
# 2                                               -2.3
# 3                                               36.3
# 4                                               17.9
#
#    Hospital return days for HF patients (EDAC-30 HF) (Higher Estimate)  \
# 0                                               39.6
# 1                                               36.5
# 2                                               16.8
# 3                                               75.3
# 4                                               45.6
#
#    Hospital return days for HF patients (EDAC-30 HF) (Lower Estimate)  \
# 0                                                4.8
# 1                                              -15.3
# 2                                              -18.8
# 3                                                1.9
# 4                                               -4.8
#
#    Hospital return days for HF patients (EDAC-30 HF) (Number of Patients)  \
# 0                                              618.0
# 1                                              145.0
# 2                                              456.0
# 3                                               44.0
# 4                                              268.0
#
#    Hospital return days for HF patients (EDAC-30 HF) (Number of Patients Returned)  \
# 0                                              211.0
# 1                                               48.0
# 2                                              136.0
# 3                                               22.0
# 4                                               73.0
#
#    Hospital return days for PN patients (EDAC-30 PN) (Denominator)  \
# 0                                              436.0
# 1                                              361.0
# 2                                              538.0
# 3                                               99.0
# 4                                              346.0
#
#    Hospital return days for PN patients (EDAC-30 PN) (Score)  \
# 0                                               -1.5
# 1                                                2.2
# 2                                               42.3
# 3                                              -12.6
# 4                                                7.7
#
#    Hospital return days for PN patients (EDAC-30 PN) (Higher Estimate)  \
# 0                                               16.7
# 1                                               19.1
# 2                                               62.6
# 3                                                6.9
# 4                                               28.0
#
#    Hospital return days for PN patients (EDAC-30 PN) (Lower Estimate)  \
# 0                                              -17.3
# 1                                              -12.2
# 2                                               24.5
# 3                                              -29.0
# 4                                               -9.5
#
#    Hospital return days for PN patients (EDAC-30 PN) (Number of Patients)  \
# 0                                              412.0
# 1                                              328.0
# 2                                              499.0
# 3                                               91.0
# 4                                              317.0
#
#    Hospital return days for PN patients (EDAC-30 PN) (Number of Patients Returned)  \
# 0                                               99.0
# 1                                               98.0
# 2                                              147.0
# 3                                               23.0
# 4                                               85.0
#
#    Inpatient admit rate for patients receiving outpatient chemo (OP-35 ADM) (Score)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Inpatient admit rate for patients receiving outpatient chemo (OP-35 ADM) (Higher Estimate)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Inpatient admit rate for patients receiving outpatient chemo (OP-35 ADM) (Lower Estimate)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Rate of unplanned visits after colonoscopy (per 1K) (OP-32) (Denominator)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Rate of unplanned visits after colonoscopy (per 1K) (OP-32) (Score)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Rate of unplanned visits after colonoscopy (per 1K) (OP-32) (Higher Estimate)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Rate of unplanned visits after colonoscopy (per 1K) (OP-32) (Lower Estimate)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Ratio of unplanned visits after outpatient surgery (OP-36) (Denominator)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Ratio of unplanned visits after outpatient surgery (OP-36) (Score)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Ratio of unplanned visits after outpatient surgery (OP-36) (Higher Estimate)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Ratio of unplanned visits after outpatient surgery (OP-36) (Lower Estimate)
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
ttdf = tdf.drop(labels=['Start Date', 'End Date'], axis=1)
ttdf.drop_duplicates(inplace=True)
print(ttdf.shape)
# Out:
# (346283, 69)

# %%
start_time = time.time()
ttdf['marker'] = ttdf['Facility ID'] + ' | ' + ttdf['Facility Name']  + ' | ' + ttdf['file_month'] + ' | ' + ttdf['file_year']
end_time = time.time()
print("Run time = {:.3f} seconds".format(end_time - start_time))
print(ttdf.shape)

start_time = time.time()
column = ttdf.pop('marker')
ttdf.insert(0, column.name, column)
end_time = time.time()
print("Run time = {:.3f} seconds".format(end_time - start_time))
print(ttdf.shape)

start_time = time.time()
ttdf.drop_duplicates(inplace=True)
end_time = time.time()
print("Run time = {:.3f} seconds".format(end_time - start_time))
print(ttdf.shape)

start_time = time.time()
collapsed_df = ttdf.groupby(ttdf.marker).apply(lambda group: group.ffill().bfill().head(1))
end_time = time.time()
print("Run time = {:.3f} seconds".format(end_time - start_time))
print(ttdf.shape)

start_time = time.time()
ttdf = collapsed_df.reset_index(drop=True)
end_time = time.time()
print("Run time = {:.3f} seconds".format(end_time - start_time))
print(ttdf.shape)

start_time = time.time()
ttdf.drop_duplicates(inplace=True)
end_time = time.time()
print("Run time = {:.3f} seconds".format(end_time - start_time))
print(ttdf.shape)

ttdf.head()
# Out:
# Run time = 0.214 seconds
# (346283, 70)
# Run time = 0.003 seconds
# (346283, 70)
# Run time = 0.956 seconds
# (346283, 70)
# Run time = 1397.064 seconds
# (346283, 70)
# Run time = 0.078 seconds
# (111463, 70)
# Run time = 0.287 seconds
# (111463, 70)
#                                               marker Facility ID  \
# 0  010001 | SOUTHEAST ALABAMA MEDICAL CENTER | 01...      010001
# 1  010001 | SOUTHEAST ALABAMA MEDICAL CENTER | 01...      010001
# 2  010001 | SOUTHEAST ALABAMA MEDICAL CENTER | 01...      010001
# 3  010001 | SOUTHEAST ALABAMA MEDICAL CENTER | 03...      010001
# 4  010001 | SOUTHEAST ALABAMA MEDICAL CENTER | 03...      010001
#
#                       Facility Name file_month file_year  \
# 0  SOUTHEAST ALABAMA MEDICAL CENTER         01      2018
# 1  SOUTHEAST ALABAMA MEDICAL CENTER         01      2020
# 2  SOUTHEAST ALABAMA MEDICAL CENTER         01      2021
# 3  SOUTHEAST ALABAMA MEDICAL CENTER         03      2019
# 4  SOUTHEAST ALABAMA MEDICAL CENTER         03      2021
#
#    30-Day HF Readmission Rate (READM-30 HF) (Denominator)  \
# 0                                             1052.0
# 1                                             1114.0
# 2                                             1106.0
# 3                                             1060.0
# 4                                             1106.0
#
#    30-Day HF Readmission Rate (READM-30 HF) (Score)  \
# 0                                              20.9
# 1                                              22.6
# 2                                              23.4
# 3                                              21.8
# 4                                              23.4
#
#    30-Day HF Readmission Rate (READM-30 HF) (Higher Estimate)  \
# 0                                               23.1
# 1                                               24.8
# 2                                               25.7
# 3                                               24.1
# 4                                               25.7
#
#    30-Day HF Readmission Rate (READM-30 HF) (Lower Estimate)  \
# 0                                               18.9
# 1                                               20.5
# 2                                               21.4
# 3                                               19.8
# 4                                               21.4
#
#    30-Day Hospital-Wide All-Cause Unplanned Readmission Rate (READM-30 HOSP-WIDE) (Denominator)  \
# 0                                             5411.0
# 1                                             4659.0
# 2                                             4474.0
# 3                                             5232.0
# 4                                             4474.0
#
#    30-Day Hospital-Wide All-Cause Unplanned Readmission Rate (READM-30 HOSP-WIDE) (Score)  \
# 0                                               15.6
# 1                                               15.4
# 2                                               15.6
# 3                                               15.4
# 4                                               15.6
#
#    30-Day Hospital-Wide All-Cause Unplanned Readmission Rate (READM-30 HOSP-WIDE) (Higher Estimate)  \
# 0                                               17.3
# 1                                               17.0
# 2                                               17.4
# 3                                               17.0
# 4                                               17.4
#
#    30-Day Hospital-Wide All-Cause Unplanned Readmission Rate (READM-30 HOSP-WIDE) (Lower Estimate)  \
# 0                                               14.2
# 1                                               13.9
# 2                                               14.0
# 3                                               13.9
# 4                                               14.0
#
#    30-Day Pneumonia Readmission Rate (READM-30 PN) (Denominator)  \
# 0                                              656.0
# 1                                              604.0
# 2                                              594.0
# 3                                              603.0
# 4                                              594.0
#
#    30-Day Pneumonia Readmission Rate (READM-30 PN) (Score)  \
# 0                                               18.5
# 1                                               16.8
# 2                                               15.4
# 3                                               17.4
# 4                                               15.4
#
#    30-Day Pneumonia Readmission Rate (READM-30 PN) (Higher Estimate)  \
# 0                                               21.2
# 1                                               19.2
# 2                                               17.7
# 3                                               20.0
# 4                                               17.7
#
#    30-Day Pneumonia Readmission Rate (READM-30 PN) (Lower Estimate)  \
# 0                                               16.1
# 1                                               14.6
# 2                                               13.3
# 3                                               15.0
# 4                                               13.3
#
#    30-Day Readmission Rate (READM-30 COPD) (Denominator)  \
# 0                                              615.0
# 1                                              493.0
# 2                                              443.0
# 3                                              568.0
# 4                                              443.0
#
#    30-Day Readmission Rate (READM-30 COPD) (Score)  \
# 0                                             19.7
# 1                                             19.8
# 2                                             20.7
# 3                                             19.4
# 4                                             20.7
#
#    30-Day Readmission Rate (READM-30 COPD) (Higher Estimate)  \
# 0                                               22.3
# 1                                               22.7
# 2                                               23.7
# 3                                               22.1
# 4                                               23.7
#
#    30-Day Readmission Rate (READM-30 COPD) (Lower Estimate)  \
# 0                                               17.3
# 1                                               17.4
# 2                                               18.1
# 3                                               17.0
# 4                                               18.1
#
#    30-Day Readmission Rate after hip/knee replacement (READM-30 HIP-KNEE) (Denominator)  \
# 0                                              342.0
# 1                                              301.0
# 2                                              258.0
# 3                                              335.0
# 4                                              258.0
#
#    30-Day Readmission Rate after hip/knee replacement (READM-30 HIP-KNEE) (Score)  \
# 0                                                4.7
# 1                                                4.7
# 2                                                4.6
# 3                                                4.3
# 4                                                4.6
#
#    30-Day Readmission Rate after hip/knee replacement (READM-30 HIP-KNEE) (Higher Estimate)  \
# 0                                                6.4
# 1                                                6.3
# 2                                                6.3
# 3                                                5.8
# 4                                                6.3
#
#    30-Day Readmission Rate after hip/knee replacement (READM-30 HIP-KNEE) (Lower Estimate)  \
# 0                                                3.5
# 1                                                3.5
# 2                                                3.4
# 3                                                3.2
# 4                                                3.4
#
#    30-Day Readmission Rate for stroke patients (READM-30 STK) (Denominator)  \
# 0                                              568.0
# 1                                                NaN
# 2                                                NaN
# 3                                              610.0
# 4                                                NaN
#
#    30-Day Readmission Rate for stroke patients (READM-30 STK) (Score)  \
# 0                                               12.2
# 1                                                NaN
# 2                                                NaN
# 3                                               12.4
# 4                                                NaN
#
#    30-Day Readmission Rate for stroke patients (READM-30 STK) (Higher Estimate)  \
# 0                                               14.5
# 1                                                NaN
# 2                                                NaN
# 3                                               14.7
# 4                                                NaN
#
#    30-Day Readmission Rate for stroke patients (READM-30 STK) (Lower Estimate)  \
# 0                                               10.2
# 1                                                NaN
# 2                                                NaN
# 3                                               10.5
# 4                                                NaN
#
#    AMI 30-Day Readmission Rate (READM-30 AMI) (Denominator)  \
# 0                                              810.0
# 1                                              742.0
# 2                                              620.0
# 3                                              798.0
# 4                                              620.0
#
#    AMI 30-Day Readmission Rate (READM-30 AMI) (Score)  \
# 0                                               16.1
# 1                                               16.2
# 2                                               16.3
# 3                                               15.9
# 4                                               16.3
#
#    AMI 30-Day Readmission Rate (READM-30 AMI) (Higher Estimate)  \
# 0                                               18.2
# 1                                               18.5
# 2                                               18.8
# 3                                               18.2
# 4                                               18.8
#
#    AMI 30-Day Readmission Rate (READM-30 AMI) (Lower Estimate)  \
# 0                                               14.2
# 1                                               14.0
# 2                                               14.1
# 3                                               13.8
# 4                                               14.1
#
#    CABG 30-Day Readmission Rate (READM-30 CABG) (Denominator)  \
# 0                                              275.0
# 1                                              279.0
# 2                                              268.0
# 3                                              290.0
# 4                                              268.0
#
#    CABG 30-Day Readmission Rate (READM-30 CABG) (Score)  \
# 0                                               14.3
# 1                                               15.6
# 2                                               14.9
# 3                                               14.9
# 4                                               14.9
#
#    CABG 30-Day Readmission Rate (READM-30 CABG) (Higher Estimate)  \
# 0                                               17.7
# 1                                               19.3
# 2                                               18.6
# 3                                               18.3
# 4                                               18.6
#
#    CABG 30-Day Readmission Rate (READM-30 CABG) (Lower Estimate)  \
# 0                                               11.5
# 1                                               12.5
# 2                                               11.9
# 3                                               12.0
# 4                                               11.9
#
#    ED visit rate for patients receiving outpatient chemo (OP-35 ED) (Denominator)  \
# 0                                                NaN
# 1                                              190.0
# 2                                              192.0
# 3                                                NaN
# 4                                              192.0
#
#    ED visit rate for patients receiving outpatient chemo (OP-35 ED) (Score)  \
# 0                                                NaN
# 1                                                7.1
# 2                                                6.7
# 3                                                NaN
# 4                                                6.7
#
#    ED visit rate for patients receiving outpatient chemo (OP-35 ED) (Higher Estimate)  \
# 0                                                NaN
# 1                                                9.9
# 2                                                9.4
# 3                                                NaN
# 4                                                9.4
#
#    ED visit rate for patients receiving outpatient chemo (OP-35 ED) (Lower Estimate)  \
# 0                                                NaN
# 1                                                5.0
# 2                                                4.6
# 3                                                NaN
# 4                                                4.6
#
#    Hospital return days for AMI patients (EDAC-30 AMI) (Denominator)  \
# 0                                              810.0
# 1                                              742.0
# 2                                              620.0
# 3                                              798.0
# 4                                              620.0
#
#    Hospital return days for AMI patients (EDAC-30 AMI) (Score)  \
# 0                                               -5.1
# 1                                               -0.8
# 2                                                7.0
# 3                                               -5.9
# 4                                                7.0
#
#    Hospital return days for AMI patients (EDAC-30 AMI) (Higher Estimate)  \
# 0                                                6.2
# 1                                               10.6
# 2                                               21.7
# 3                                                4.8
# 4                                               21.7
#
#    Hospital return days for AMI patients (EDAC-30 AMI) (Lower Estimate)  \
# 0                                              -15.5
# 1                                              -11.6
# 2                                               -5.4
# 3                                              -15.9
# 4                                               -5.4
#
#    Hospital return days for AMI patients (EDAC-30 AMI) (Number of Patients)  \
# 0                                                NaN
# 1                                                NaN
# 2                                              589.0
# 3                                                NaN
# 4                                              589.0
#
#    Hospital return days for AMI patients (EDAC-30 AMI) (Number of Patients Returned)  \
# 0                                                NaN
# 1                                                NaN
# 2                                              171.0
# 3                                                NaN
# 4                                              171.0
#
#    Hospital return days for HF patients (EDAC-30 HF) (Denominator)  \
# 0                                             1052.0
# 1                                             1114.0
# 2                                             1106.0
# 3                                             1060.0
# 4                                             1106.0
#
#    Hospital return days for HF patients (EDAC-30 HF) (Score)  \
# 0                                               12.3
# 1                                               17.8
# 2                                               21.6
# 3                                               17.1
# 4                                               21.6
#
#    Hospital return days for HF patients (EDAC-30 HF) (Higher Estimate)  \
# 0                                               27.0
# 1                                               31.5
# 2                                               36.3
# 3                                               31.7
# 4                                               36.3
#
#    Hospital return days for HF patients (EDAC-30 HF) (Lower Estimate)  \
# 0                                               -1.0
# 1                                                4.5
# 2                                                7.8
# 3                                                3.4
# 4                                                7.8
#
#    Hospital return days for HF patients (EDAC-30 HF) (Number of Patients)  \
# 0                                                NaN
# 1                                                NaN
# 2                                              842.0
# 3                                                NaN
# 4                                              842.0
#
#    Hospital return days for HF patients (EDAC-30 HF) (Number of Patients Returned)  \
# 0                                                NaN
# 1                                                NaN
# 2                                              310.0
# 3                                                NaN
# 4                                              310.0
#
#    Hospital return days for PN patients (EDAC-30 PN) (Denominator)  \
# 0                                                NaN
# 1                                              604.0
# 2                                              594.0
# 3                                              603.0
# 4                                              594.0
#
#    Hospital return days for PN patients (EDAC-30 PN) (Score)  \
# 0                                                NaN
# 1                                               -7.8
# 2                                              -20.6
# 3                                                8.4
# 4                                              -20.6
#
#    Hospital return days for PN patients (EDAC-30 PN) (Higher Estimate)  \
# 0                                                NaN
# 1                                                6.0
# 2                                               -7.8
# 3                                               24.4
# 4                                               -7.8
#
#    Hospital return days for PN patients (EDAC-30 PN) (Lower Estimate)  \
# 0                                                NaN
# 1                                              -21.3
# 2                                              -32.9
# 3                                               -5.9
# 4                                              -32.9
#
#    Hospital return days for PN patients (EDAC-30 PN) (Number of Patients)  \
# 0                                                NaN
# 1                                                NaN
# 2                                              540.0
# 3                                                NaN
# 4                                              540.0
#
#    Hospital return days for PN patients (EDAC-30 PN) (Number of Patients Returned)  \
# 0                                                NaN
# 1                                                NaN
# 2                                              132.0
# 3                                                NaN
# 4                                              132.0
#
#    Inpatient admit rate for patients receiving outpatient chemo (OP-35 ADM) (Score)  \
# 0                                                NaN
# 1                                               10.8
# 2                                               11.3
# 3                                                NaN
# 4                                               11.3
#
#    Inpatient admit rate for patients receiving outpatient chemo (OP-35 ADM) (Higher Estimate)  \
# 0                                                NaN
# 1                                               13.9
# 2                                               14.2
# 3                                                NaN
# 4                                               14.2
#
#    Inpatient admit rate for patients receiving outpatient chemo (OP-35 ADM) (Lower Estimate)  \
# 0                                                NaN
# 1                                                8.3
# 2                                                8.8
# 3                                                NaN
# 4                                                8.8
#
#    Rate of unplanned visits after colonoscopy (per 1K) (OP-32) (Denominator)  \
# 0                                              255.0
# 1                                              606.0
# 2                                              511.0
# 3                                              205.0
# 4                                              511.0
#
#    Rate of unplanned visits after colonoscopy (per 1K) (OP-32) (Score)  \
# 0                                               14.8
# 1                                               13.4
# 2                                               14.1
# 3                                               13.9
# 4                                               14.1
#
#    Rate of unplanned visits after colonoscopy (per 1K) (OP-32) (Higher Estimate)  \
# 0                                               21.0
# 1                                               18.1
# 2                                               19.2
# 3                                               19.2
# 4                                               19.2
#
#    Rate of unplanned visits after colonoscopy (per 1K) (OP-32) (Lower Estimate)  \
# 0                                               10.2
# 1                                                9.8
# 2                                               10.4
# 3                                               10.0
# 4                                               10.4
#
#    Ratio of unplanned visits after outpatient surgery (OP-36) (Denominator)  \
# 0                                                NaN
# 1                                              993.0
# 2                                             1003.0
# 3                                                NaN
# 4                                             1003.0
#
#    Ratio of unplanned visits after outpatient surgery (OP-36) (Score)  \
# 0                                                NaN
# 1                                                0.8
# 2                                                0.9
# 3                                                NaN
# 4                                                0.9
#
#    Ratio of unplanned visits after outpatient surgery (OP-36) (Higher Estimate)  \
# 0                                                NaN
# 1                                                1.0
# 2                                                1.0
# 3                                                NaN
# 4                                                1.0
#
#    Ratio of unplanned visits after outpatient surgery (OP-36) (Lower Estimate)
# 0                                                NaN
# 1                                                0.7
# 2                                                0.7
# 3                                                NaN
# 4                                                0.7

# %% [markdown]
# ## Save dataframe

# %%
ttdf.drop(labels=['marker'], axis=1, inplace=True)
ttdf.to_pickle('~/GitHub/hospitals-data-archive/dataframes/partial_dataframes/unplanned_visits_df.pkl.gz', protocol=5, compression='gzip')

# %%
m1 = list(ttdf)
ls = ['Facility ID','Facility Name','file_month','file_year']
for l in ls: 
    m1.remove(l)

# %% [markdown]
# ## Save measurement dates

# %%
# Columns to keep as is
id_cols = ['Facility ID', 'Facility Name', 'file_month', 'file_year', 'Start Date', 'End Date']

# Melt the specific columns and create the 'Measure' and 'Score' columns
measures_df = tdf.melt(id_vars=id_cols, var_name='Measure Name', value_name='Score')
measures_df.drop(labels=['Score', 'Facility ID', 'Facility Name'], axis=1, inplace=True)

print(measures_df.shape)
measures_df.drop_duplicates(inplace=True)
measures_df.reset_index(drop=True, inplace=True)
print(measures_df.shape)

measures_df['Start Date'] = pd.to_datetime(measures_df['Start Date'])
measures_df['End Date'] = pd.to_datetime(measures_df['End Date'])
measures_df.to_csv('~/GitHub/hospitals-data-archive/measure_dates/unplanned_visits_df.csv')

measures_df.head()
# Out:
# (22508395, 5)
# (6240, 5)
#   file_month file_year Start Date   End Date  \
# 0         01      2023 2018-07-01 2021-06-30
# 1         04      2023 2018-07-01 2021-06-30
# 2         07      2023 2019-07-01 2022-06-30
# 3         10      2023 2019-07-01 2022-06-30
# 4         01      2022 2017-07-01 2019-12-01
#
#                                         Measure Name
# 0  30-Day HF Readmission Rate (READM-30 HF) (Deno...
# 1  30-Day HF Readmission Rate (READM-30 HF) (Deno...
# 2  30-Day HF Readmission Rate (READM-30 HF) (Deno...
# 3  30-Day HF Readmission Rate (READM-30 HF) (Deno...
# 4  30-Day HF Readmission Rate (READM-30 HF) (Deno...

# %%
m2 = measures_df['Measure Name'].unique().tolist()
sorted(m1) == sorted(m2)
# Out:
# True
