# %% [markdown]
# # Generate Outpatient Imaging Efficiency dataframe

# %%
import pandas as pd
import numpy as np
import warnings
from IPython.utils import io
import sys
import time

warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

main_dir = '~/Desktop/Rush/CMS_HospitalArchives/'

# %% [markdown]
# ## Define Custom Functions

# %%
def curate(df):

    try:
        df = df[df['Facility ID'] != np.nan]
        df['Facility ID'] = df['Facility ID'].values.astype(str)
        
        ids = df['Facility ID'].tolist()
        ids2 = []
        for i in ids:
            if len(i) < 6:
                i = '0' + i
            ids2.append(i)
        df['Facility ID'] = ids2
        
    except:
        pass
    try:
        df = df[df['Facility Name'] != np.nan]
    except:
        pass
    
    for c in list(df):    
        try:
            df[c] = df[c].str.replace("\t","")
        except:
            pass

    return df


def rename_and_fill(df):
    
    cols1 = ['Provider ID', "Measure Start Date", "Measure End Date",
             'Hospital Name', 'Address 1', 'City/Town', 'County/Parish',
             'Telephone Number']
    
    cols2 = ['Facility ID', "Start Date", "End Date",
             'Facility Name', 'Address', 'City', 'County Name',
             'Phone Number']
    
    for i, col in enumerate(cols1):
        if col in list(df):
            df.rename(columns={col: cols2[i]}, inplace=True)
            
            
    l = list(df)
    l = list(set([x for x in l if l.count(x) > 1]))
    if len(l) > 0:
        print('duplicates:', l)
        sys.exit()
        
    return df


def process2(df, lists, yr, mo):
    df = rename_and_fill(df)
    df = curate(df)
    lists.append(list(df))
    df['file_month'] = [mo]* df.shape[0]
    df['file_year'] = [yr]* df.shape[0]
    df = df.reindex(sorted(df.columns), axis=1)
    return df, lists

# %% [markdown]
# ## Load Files

# %%
df_list = []
lists = []

yrs = ['2023', '2023', '2023', '2023',
       '2022', '2022', '2022', '2022',
       '2021','2021','2021', '2021', '2021',
       '2020', '2020', '2020', '2020', 
       '2019', '2019', '2019', '2019', 
       '2018', '2018', '2018', '2018',
       '2017', '2017', '2017',
       '2016', '2016', '2016', '2016',
       '2015', '2015', '2015', '2015', '2015', '2015',
       '2014', '2014', '2014',
       ]

mos = ['01', '04', '07', '10',
       '01', '04', '07', '10',
       '01', '03', '04', '07', '10', 
       '10', '07', '04', '01', 
       '10', '07', '04', '03', 
       '10', '07', '05', '01',
       '10', '07', '04',
       '12', '11', '08', '05',
       '12', '10', '07', '05', '04', '01',
       '12', '10', '07',
       ]

subdirs = ['2023/hospitals_01_2023/Outpatient_Imaging_Efficiency-Hospital.csv', 
           '2023/hospitals_04_2023/Outpatient_Imaging_Efficiency-Hospital.csv',
           '2023/hospitals_07_2023/Outpatient_Imaging_Efficiency-Hospital.csv',
           '2023/hospitals_10_2023/Outpatient_Imaging_Efficiency-Hospital.csv',
           
           '2022/hospitals_01_2022/Outpatient_Imaging_Efficiency-Hospital.csv', 
           '2022/hospitals_04_2022/Outpatient_Imaging_Efficiency-Hospital.csv',
           '2022/hospitals_07_2022/Outpatient_Imaging_Efficiency-Hospital.csv',
           '2022/hospitals_10_2022/Outpatient_Imaging_Efficiency-Hospital.csv',
           
           '2021/hospitals_01_2021/Outpatient_Imaging_Efficiency-Hospital.csv',
           '2021/hospitals_03_2021/Outpatient_Imaging_Efficiency-Hospital.csv',
           '2021/hospitals_04_2021/Outpatient_Imaging_Efficiency-Hospital.csv',
           '2021/hospitals_07_2021/Outpatient_Imaging_Efficiency-Hospital.csv',
           '2021/hospitals_10_2021/Outpatient_Imaging_Efficiency-Hospital.csv',
           
           '2020/hospitals_archive_10_2020/Outpatient_Imaging_Efficiency_Hospital.csv',
           '2020/hospitals_archive_07_2020/Outpatient_Imaging_Efficiency_Hospital.csv',
           '2020/HOSArchive_Revised_Flatfiles_20200422/Outpatient Imaging Efficiency - Hospital.csv',
           '2020/HOSArchive_Revised_Flatfiles_20200129/Outpatient Imaging Efficiency - Hospital.csv',
           
           '2019/HOSArchive_Revised_Flatfiles_20191030/Outpatient Imaging Efficiency - Hospital.csv',
           '2019/HOSArchive_Revised_Flatfiles_20190702/Outpatient Imaging Efficiency - Hospital.csv',
           '2019/HOSArchive_Revised_FlatFiles_20190424/Outpatient Imaging Efficiency - Hospital.csv',
           '2019/HOSArchive_Revised_Flatfiles_20190321/Outpatient Imaging Efficiency - Hospital.csv',
           
           '2018/HOSArchive_Revised_FlatFiles_20181031/Outpatient Imaging Efficiency - Hospital.csv',
           '2018/HOSArchive_Revised_FlatFiles_20180725/Outpatient Imaging Efficiency - Hospital.csv', 
           '2018/HOSArchive_Revised_FlatFiles_20180523/Outpatient Imaging Efficiency - Hospital.csv',
           '2018/HOSArchive_Revised_FlatFiles_20180126/Outpatient Imaging Efficiency - Hospital.csv',
           
           '2017/HOSArchive_Revised_FlatFiles_20171024/Outpatient Imaging Efficiency - Hospital.csv',
           '2017/HOSArchive_Revised_FlatFiles_20170726/Outpatient Imaging Efficiency - Hospital.csv', 
           '2017/HOSArchive_Revised_Flatfiles_20170428/Outpatient Imaging Efficiency - Hospital.csv', 
           
           '2016/HOSArchive_Revised_Flatfiles_20161219/Outpatient Imaging Efficiency - Hospital.csv',
           '2016/Hospital_Revised_FlatFiles_20161110/Outpatient Imaging Efficiency - Hospital.csv', 
           '2016/HOSArchive_Revised_FlatFiles_20160810/Outpatient Imaging Efficiency - Hospital.csv',
           '2016/HOSArchive_Revised_FlatFiles_20160504/Outpatient Imaging Efficiency - Hospital.csv',
           
           '2015/HOSArchive_Revised_FlatFiles_20151210/Outpatient Imaging Efficiency - Hospital.csv',
           '2015/HOSArchive_Revised_FlatFiles_20151008/Outpatient Imaging Efficiency - Hospital.csv',
           '2015/HOSArchive_Revised_FlatFiles_20150716/Outpatient Imaging Efficiency - Hospital.csv',
           '2015/HOSArchive_Revised_Flatfiles_20150506/Outpatient Imaging Efficiency - Hospital.csv',
           '2015/HOSArchive_Revised_Flatfiles_20150416/Outpatient Imaging Efficiency - Hospital.csv',
           '2015/HOSArchive_Revised_Flatfiles_20150122/Outpatient Imaging Efficiency - Hospital.csv',
           
           '2014/HOSArchive_Revised_Flatfiles_20141218/Outpatient Imaging Efficiency - Hospital.csv',
           '2014/HOSArchive_Revised_Flatfiles_20141023/Outpatient Imaging Efficiency - Hospital.csv',
           '2014/HOSArchive_Revised_Flatfiles_20140717/Outpatient Imaging Efficiency - Hospital.csv',
           ]

for i, subdir in enumerate(subdirs):
    with io.capture_output() as captured: df = pd.read_csv(main_dir + subdir, encoding = "ISO-8859-1")
    print(subdir + ' :  (rows, columns) =', df.shape)
    df, lists = process2(df, lists, yrs[i], mos[i])
    df_list.append(df)

df = pd.concat(df_list)

print('df.shape:', df.shape)
df = df[~df['Score'].isin([np.nan, float("NaN"), 'Not Available'])]
print('df.shape:', df.shape)

print(sorted(list(df)))
df.head()
# Out:
# 2023/hospitals_01_2023/Outpatient_Imaging_Efficiency-Hospital.csv :  (rows, columns) = (18704, 14)
# 2023/hospitals_04_2023/Outpatient_Imaging_Efficiency-Hospital.csv :  (rows, columns) = (18692, 14)
# 2023/hospitals_07_2023/Outpatient_Imaging_Efficiency-Hospital.csv :  (rows, columns) = (18664, 14)
# 2023/hospitals_10_2023/Outpatient_Imaging_Efficiency-Hospital.csv :  (rows, columns) = (18664, 14)
# 2022/hospitals_01_2022/Outpatient_Imaging_Efficiency-Hospital.csv :  (rows, columns) = (14028, 14)
# 2022/hospitals_04_2022/Outpatient_Imaging_Efficiency-Hospital.csv :  (rows, columns) = (14028, 14)
# 2022/hospitals_07_2022/Outpatient_Imaging_Efficiency-Hospital.csv :  (rows, columns) = (18684, 14)
# 2022/hospitals_10_2022/Outpatient_Imaging_Efficiency-Hospital.csv :  (rows, columns) = (18692, 14)
# 2021/hospitals_01_2021/Outpatient_Imaging_Efficiency-Hospital.csv :  (rows, columns) = (14130, 14)
# 2021/hospitals_03_2021/Outpatient_Imaging_Efficiency-Hospital.csv :  (rows, columns) = (14130, 14)
# 2021/hospitals_04_2021/Outpatient_Imaging_Efficiency-Hospital.csv :  (rows, columns) = (14220, 14)
# 2021/hospitals_07_2021/Outpatient_Imaging_Efficiency-Hospital.csv :  (rows, columns) = (14082, 14)
# 2021/hospitals_10_2021/Outpatient_Imaging_Efficiency-Hospital.csv :  (rows, columns) = (14049, 14)
# 2020/hospitals_archive_10_2020/Outpatient_Imaging_Efficiency_Hospital.csv :  (rows, columns) = (14118, 14)
# 2020/hospitals_archive_07_2020/Outpatient_Imaging_Efficiency_Hospital.csv :  (rows, columns) = (14136, 14)
# 2020/HOSArchive_Revised_Flatfiles_20200422/Outpatient Imaging Efficiency - Hospital.csv :  (rows, columns) = (28344, 14)
# 2020/HOSArchive_Revised_Flatfiles_20200129/Outpatient Imaging Efficiency - Hospital.csv :  (rows, columns) = (28392, 14)
# 2019/HOSArchive_Revised_Flatfiles_20191030/Outpatient Imaging Efficiency - Hospital.csv :  (rows, columns) = (28542, 14)
# 2019/HOSArchive_Revised_Flatfiles_20190702/Outpatient Imaging Efficiency - Hospital.csv :  (rows, columns) = (28548, 14)
# 2019/HOSArchive_Revised_FlatFiles_20190424/Outpatient Imaging Efficiency - Hospital.csv :  (rows, columns) = (28632, 14)
# 2019/HOSArchive_Revised_Flatfiles_20190321/Outpatient Imaging Efficiency - Hospital.csv :  (rows, columns) = (28704, 14)
# 2018/HOSArchive_Revised_FlatFiles_20181031/Outpatient Imaging Efficiency - Hospital.csv :  (rows, columns) = (28758, 14)
# 2018/HOSArchive_Revised_FlatFiles_20180725/Outpatient Imaging Efficiency - Hospital.csv :  (rows, columns) = (28782, 14)
# 2018/HOSArchive_Revised_FlatFiles_20180523/Outpatient Imaging Efficiency - Hospital.csv :  (rows, columns) = (28788, 14)
# 2018/HOSArchive_Revised_FlatFiles_20180126/Outpatient Imaging Efficiency - Hospital.csv :  (rows, columns) = (28836, 14)
# 2017/HOSArchive_Revised_FlatFiles_20171024/Outpatient Imaging Efficiency - Hospital.csv :  (rows, columns) = (28872, 14)
# 2017/HOSArchive_Revised_FlatFiles_20170726/Outpatient Imaging Efficiency - Hospital.csv :  (rows, columns) = (28872, 14)
# 2017/HOSArchive_Revised_Flatfiles_20170428/Outpatient Imaging Efficiency - Hospital.csv :  (rows, columns) = (28830, 14)
# 2016/HOSArchive_Revised_Flatfiles_20161219/Outpatient Imaging Efficiency - Hospital.csv :  (rows, columns) = (28842, 14)
# 2016/Hospital_Revised_FlatFiles_20161110/Outpatient Imaging Efficiency - Hospital.csv :  (rows, columns) = (28908, 14)
# 2016/HOSArchive_Revised_FlatFiles_20160810/Outpatient Imaging Efficiency - Hospital.csv :  (rows, columns) = (24708, 14)
# 2016/HOSArchive_Revised_FlatFiles_20160504/Outpatient Imaging Efficiency - Hospital.csv :  (rows, columns) = (24576, 14)
# 2015/HOSArchive_Revised_FlatFiles_20151210/Outpatient Imaging Efficiency - Hospital.csv :  (rows, columns) = (24624, 14)
# 2015/HOSArchive_Revised_FlatFiles_20151008/Outpatient Imaging Efficiency - Hospital.csv :  (rows, columns) = (24594, 14)
# 2015/HOSArchive_Revised_FlatFiles_20150716/Outpatient Imaging Efficiency - Hospital.csv :  (rows, columns) = (24666, 14)
# 2015/HOSArchive_Revised_Flatfiles_20150506/Outpatient Imaging Efficiency - Hospital.csv :  (rows, columns) = (24624, 14)
# 2015/HOSArchive_Revised_Flatfiles_20150416/Outpatient Imaging Efficiency - Hospital.csv :  (rows, columns) = (24624, 14)
# 2015/HOSArchive_Revised_Flatfiles_20150122/Outpatient Imaging Efficiency - Hospital.csv :  (rows, columns) = (24732, 14)
# 2014/HOSArchive_Revised_Flatfiles_20141218/Outpatient Imaging Efficiency - Hospital.csv :  (rows, columns) = (24732, 14)
# 2014/HOSArchive_Revised_Flatfiles_20141023/Outpatient Imaging Efficiency - Hospital.csv :  (rows, columns) = (24816, 14)
# 2014/HOSArchive_Revised_Flatfiles_20140717/Outpatient Imaging Efficiency - Hospital.csv :  (rows, columns) = (24816, 14)
# df.shape: (941183, 16)
# df.shape: (559173, 16)
# ['Address', 'City', 'County Name', 'End Date', 'Facility ID', 'Facility Name', 'Footnote', 'Measure ID', 'Measure Name', 'Phone Number', 'Score', 'Start Date', 'State', 'ZIP Code', 'file_month', 'file_year']
#                       Address    City County Name    End Date Facility ID  \
# 0      1108 ROSS CLARK CIRCLE  DOTHAN     HOUSTON  06/30/2021      010001
# 1      1108 ROSS CLARK CIRCLE  DOTHAN     HOUSTON  06/30/2021      010001
# 2      1108 ROSS CLARK CIRCLE  DOTHAN     HOUSTON  06/30/2021      010001
# 3      1108 ROSS CLARK CIRCLE  DOTHAN     HOUSTON  06/30/2021      010001
# 4  2505 U S HIGHWAY 431 NORTH    BOAZ    MARSHALL  06/30/2021      010005
#
#                      Facility Name Footnote Measure ID  \
# 0  SOUTHEAST HEALTH MEDICAL CENTER      NaN      OP-10
# 1  SOUTHEAST HEALTH MEDICAL CENTER      NaN      OP-13
# 2  SOUTHEAST HEALTH MEDICAL CENTER      NaN      OP-39
# 3  SOUTHEAST HEALTH MEDICAL CENTER      NaN       OP-8
# 4         MARSHALL MEDICAL CENTERS      NaN      OP-10
#
#                                         Measure Name    Phone Number Score  \
# 0                Abdomen CT Use of Contrast Material  (334) 793-8701   5.7
# 1  Outpatients who got cardiac imaging stress tes...  (334) 793-8701   6.8
# 2               Breast Cancer Screening Recall Rates  (334) 793-8701   5.5
# 3                 MRI Lumbar Spine for Low Back Pain  (334) 793-8701  42.5
# 4                Abdomen CT Use of Contrast Material  (256) 593-8310  13.8
#
#    Start Date State  ZIP Code file_month file_year
# 0  07/01/2020    AL     36301         01      2023
# 1  07/01/2020    AL     36301         01      2023
# 2  07/01/2020    AL     36301         01      2023
# 3  07/01/2020    AL     36301         01      2023
# 4  07/01/2020    AL     35957         01      2023

# %%
d = {'OP_10': 'OP-10',
     'OP_11': 'OP-11', 
     'OP_13': 'OP-13',
     'OP_14': 'OP-14',
     'OP_8': 'OP-8', 
     'OP_9': 'OP-9',
     }
df['Measure ID'].replace(to_replace = d, inplace = True)

df['Measure Name'] = df['Measure Name'] + ' (' + df['Measure ID'] + ')'
df = df.filter(items=['Facility ID', 'Facility Name', 'file_month', 'file_year',
                      'Measure Name', 'Start Date', 'End Date',
                      'Score'], axis=1)

# %%
cols = ['Facility ID', 'Facility Name', 'file_month', 'file_year', 'Start Date', 'End Date']
main_df = pd.DataFrame(columns=cols)
Measures = sorted(df['Measure Name'].unique())

for i, mi in enumerate(Measures):    
    tdf = df[df['Measure Name'] == mi]
    measures = sorted(tdf['Measure Name'].unique())
    
    df2 = pd.DataFrame(columns=cols)

    for j, m in enumerate(measures):
        tdf2 = tdf[tdf['Measure Name'] == m]
        for n in list(tdf2):
            if n == 'Measure Name' or n in cols:
                continue
            else:
                tdf2[n] = pd.to_numeric(tdf2[n], errors='coerce')
                tdf2.rename(columns={n: m + ' (' + n + ')'}, inplace=True)
        
        tdf2.drop(labels=['Measure Name'], axis=1, inplace=True)
        
        df2 = df2.merge(tdf2, on=cols, how='outer')
    
    main_df = main_df.merge(df2, on=cols, how='outer')

tdf = main_df.copy(deep=True)
del df2, main_df

print(tdf.shape)
tdf = tdf.loc[:, ~tdf.T.duplicated(keep='first')]
tdf.dropna(how='all', axis=1, inplace=True)
print(tdf.shape)
tdf.drop_duplicates(inplace=True)
print(tdf.shape)
tdf.drop_duplicates(subset = cols, inplace=True)
print(tdf.shape)
tdf.head()
# Out:
# (162666, 13)
# (162666, 13)
# (162666, 13)
# (162666, 13)
#   Facility ID                    Facility Name file_month file_year  \
# 0      010001  SOUTHEAST HEALTH MEDICAL CENTER         01      2023
# 1      010005         MARSHALL MEDICAL CENTERS         01      2023
# 2      010006     NORTH ALABAMA MEDICAL CENTER         01      2023
# 3      010007         MIZELL MEMORIAL HOSPITAL         01      2023
# 4      010008      CRENSHAW COMMUNITY HOSPITAL         01      2023
#
#    Start Date    End Date  \
# 0  07/01/2020  06/30/2021
# 1  07/01/2020  06/30/2021
# 2  07/01/2020  06/30/2021
# 3  07/01/2020  06/30/2021
# 4  07/01/2020  06/30/2021
#
#    Abdomen CT Use of Contrast Material (OP-10) (Score)  \
# 0                                                5.7
# 1                                               13.8
# 2                                               11.0
# 3                                                5.9
# 4                                                2.1
#
#    Breast Cancer Screening Recall Rates (OP-39) (Score)  \
# 0                                                5.5
# 1                                                6.7
# 2                                                9.4
# 3                                               25.8
# 4                                                NaN
#
#    MRI Lumbar Spine for Low Back Pain (OP-8) (Score)  \
# 0                                               42.5
# 1                                               54.5
# 2                                               41.2
# 3                                                NaN
# 4                                                NaN
#
#    Mammography Follow-up Rates (OP-9) (Score)  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#    Outpatients who got cardiac imaging stress tests before low-risk outpatient surgery (OP-13) (Score)  \
# 0                                                6.8
# 1                                                3.8
# 2                                                1.7
# 3                                                NaN
# 4                                                NaN
#
#    Outpatients with brain CT scans who got a sinus CT scan at the same time (OP-14) (Score)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Thorax CT Use of Contrast Material (OP-11) (Score)
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
ttdf = tdf.drop(labels=['Start Date', 'End Date'], axis=1)
ttdf.drop_duplicates(inplace=True)
print(ttdf.shape)
# Out:
# (162666, 11)

# %%
start_time = time.time()
ttdf['marker'] = ttdf['Facility ID'] + ' | ' + ttdf['Facility Name']  + ' | ' + ttdf['file_month'] + ' | ' + ttdf['file_year']
end_time = time.time()
print("Run time = {:.3f} seconds".format(end_time - start_time))
print(ttdf.shape)

start_time = time.time()
column = ttdf.pop('marker')
ttdf.insert(0, column.name, column)
end_time = time.time()
print("Run time = {:.3f} seconds".format(end_time - start_time))
print(ttdf.shape)

start_time = time.time()
ttdf.drop_duplicates(inplace=True)
end_time = time.time()
print("Run time = {:.3f} seconds".format(end_time - start_time))
print(ttdf.shape)

start_time = time.time()
collapsed_df = ttdf.groupby(ttdf.marker).apply(lambda group: group.ffill().bfill().head(1))
end_time = time.time()
print("Run time = {:.3f} seconds".format(end_time - start_time))
print(ttdf.shape)

start_time = time.time()
ttdf = collapsed_df.reset_index(drop=True)
end_time = time.time()
print("Run time = {:.3f} seconds".format(end_time - start_time))
print(ttdf.shape)

start_time = time.time()
ttdf.drop_duplicates(inplace=True)
end_time = time.time()
print("Run time = {:.3f} seconds".format(end_time - start_time))
print(ttdf.shape)

ttdf.head()
# Out:
# Run time = 0.091 seconds
# (162666, 12)
# Run time = 0.002 seconds
# (162666, 12)
# Run time = 0.173 seconds
# (162666, 12)
# Run time = 3014.647 seconds
# (162666, 12)
# Run time = 0.045 seconds
# (159402, 12)
# Run time = 0.154 seconds
# (159402, 12)
#                                               marker Facility ID  \
# 0  010001 | SOUTHEAST ALABAMA MEDICAL CENTER | 01...      010001
# 1  010001 | SOUTHEAST ALABAMA MEDICAL CENTER | 01...      010001
# 2  010001 | SOUTHEAST ALABAMA MEDICAL CENTER | 01...      010001
# 3  010001 | SOUTHEAST ALABAMA MEDICAL CENTER | 01...      010001
# 4  010001 | SOUTHEAST ALABAMA MEDICAL CENTER | 03...      010001
#
#                       Facility Name file_month file_year  \
# 0  SOUTHEAST ALABAMA MEDICAL CENTER         01      2015
# 1  SOUTHEAST ALABAMA MEDICAL CENTER         01      2018
# 2  SOUTHEAST ALABAMA MEDICAL CENTER         01      2020
# 3  SOUTHEAST ALABAMA MEDICAL CENTER         01      2021
# 4  SOUTHEAST ALABAMA MEDICAL CENTER         03      2019
#
#    Abdomen CT Use of Contrast Material (OP-10) (Score)  \
# 0                                                4.6
# 1                                                9.0
# 2                                                8.0
# 3                                                7.2
# 4                                                6.5
#
#    Breast Cancer Screening Recall Rates (OP-39) (Score)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    MRI Lumbar Spine for Low Back Pain (OP-8) (Score)  \
# 0                                               29.3
# 1                                               35.1
# 2                                               35.2
# 3                                               38.9
# 4                                               36.1
#
#    Mammography Follow-up Rates (OP-9) (Score)  \
# 0                                         5.0
# 1                                         4.6
# 2                                         5.8
# 3                                         NaN
# 4                                         5.5
#
#    Outpatients who got cardiac imaging stress tests before low-risk outpatient surgery (OP-13) (Score)  \
# 0                                                8.0
# 1                                                5.9
# 2                                                6.1
# 3                                                2.8
# 4                                                7.5
#
#    Outpatients with brain CT scans who got a sinus CT scan at the same time (OP-14) (Score)  \
# 0                                                2.9
# 1                                                1.6
# 2                                                1.7
# 3                                                NaN
# 4                                                0.7
#
#    Thorax CT Use of Contrast Material (OP-11) (Score)
# 0                                                2.5
# 1                                                1.5
# 2                                                1.8
# 3                                                NaN
# 4                                                1.1

# %%
ttdf.drop(labels=['marker'], axis=1, inplace=True)
ttdf.to_pickle('~/GitHub/hospitals-data-archive/dataframes/partial_dataframes/Outpatient_Imaging_Efficiency_df.pkl.gz', protocol=5, compression='gzip')

# %%
m1 = list(ttdf)
ls = ['Facility ID','Facility Name','file_month','file_year']
for l in ls: 
    m1.remove(l)

# %% [markdown]
# ## Save measurement dates

# %%
# Columns to keep as is
id_cols = ['Facility ID', 'Facility Name', 'file_month', 'file_year', 'Start Date', 'End Date']

# Melt the specific columns and create the 'Measure' and 'Score' columns
measures_df = tdf.melt(id_vars=id_cols, var_name='Measure Name', value_name='Score')
measures_df.drop(labels=['Score', 'Facility ID', 'Facility Name'], axis=1, inplace=True)

print(measures_df.shape)
measures_df.drop_duplicates(inplace=True)
measures_df.reset_index(drop=True, inplace=True)
print(measures_df.shape)

measures_df['Start Date'] = pd.to_datetime(measures_df['Start Date'])
measures_df['End Date'] = pd.to_datetime(measures_df['End Date'])
measures_df.to_csv('~/GitHub/hospitals-data-archive/measure_dates/Outpatient_Imaging_Efficiency_df.csv')

measures_df.head()
# Out:
# (1138662, 5)
# (294, 5)
#   file_month file_year Start Date   End Date  \
# 0         01      2023 2020-07-01 2021-06-30
# 1         04      2023 2020-07-01 2021-06-30
# 2         07      2023 2021-07-01 2022-06-30
# 3         10      2023 2021-07-01 2022-06-30
# 4         01      2022 2019-07-01 2019-12-31
#
#                                         Measure Name
# 0  Abdomen CT Use of Contrast Material (OP-10) (S...
# 1  Abdomen CT Use of Contrast Material (OP-10) (S...
# 2  Abdomen CT Use of Contrast Material (OP-10) (S...
# 3  Abdomen CT Use of Contrast Material (OP-10) (S...
# 4  Abdomen CT Use of Contrast Material (OP-10) (S...

# %%
m2 = measures_df['Measure Name'].unique().tolist()
sorted(m1) == sorted(m2)
# Out:
# True
