# %% [markdown]
# # Generate Unplanned Visits dataframe

# %%
import pandas as pd
import numpy as np
import warnings
from IPython.utils import io
import sys
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

main_dir = '/Users/kenlocey/Desktop/Rush/CMS_HospitalArchives/'

# %% [markdown]
# ## Define Custom Functions

# %%
def check_lists(lists):
    for i, ls in enumerate(lists):
        for i2, ls2 in enumerate(lists):
            for i3 in ls:
                if i3 not in ls2:
                    print('\n')
                    print(i3 + ': NOT FOUND IN')
                    print(ls2)
                    sys.exit()
                        
                        
def curate(df):

    try:
        df = df[df['Facility ID'] != np.nan]
        df['Facility ID'] = df['Facility ID'].values.astype(str)
        
        ids = df['Facility ID'].tolist()
        ids2 = []
        for i in ids:
            if len(i) < 6:
                i = '0' + i
            ids2.append(i)
        df['Facility ID'] = ids2
        
    except:
        pass
    try:
        df = df[df['Facility Name'] != np.nan]
    except:
        pass
    
    for c in list(df):    
        try:
            df[c] = df[c].str.replace("\t","")
        except:
            pass

    return df


def rename_and_fill(df):
    
    cols1 = ['Provider ID', "Measure Start Date", "Measure End Date",
             'Hospital Name', 
             ]
    
    
    cols2 = ['Facility ID', "Start Date", "End Date",
             'Facility Name',
             ]
    
    for i, col in enumerate(cols1):
        if col in list(df):
            df.rename(columns={col: cols2[i]}, inplace=True)
            
            
    cols = ['Number of Patients', 'Number of Patients Returned',
            ]
    
    for col in cols:
        if col not in list(df):
            df[col] = float('NaN')
    
    l = list(df)
    l = list(set([x for x in l if l.count(x) > 1]))
    if len(l) > 0:
        print('duplicates:', l)
        sys.exit()
        
    return df


def process2(df, lists, yr, mo):
    df = rename_and_fill(df)
    df = curate(df)
    lists.append(list(df))
    df['file_month'] = [mo]* df.shape[0]
    df['file_year'] = [yr]* df.shape[0]
    df = df.reindex(sorted(df.columns), axis=1)
    return df, lists

# %% [markdown]
# ## Load Files

# %%
df_list = []
lists = []

yrs = ['2023', '2023', 
       '2022', '2022', '2022',
       '2021','2021','2021', '2021', '2021',
       '2020', '2020', '2020', '2020', 
       '2019', '2019', '2019', '2019', 
       '2018', '2018', '2018', '2018',
       ]

mos = ['01', '04',
       '01', '04', '07',
       '01', '03', '04', '07', '10', 
       '10', '07', '04', '01', 
       '10', '07', '04', '03', 
       '10', '07', '05', '01',
       ]

subdirs = ['2023/hospitals_01_2023/Unplanned_Hospital_Visits-Hospital.csv', 
           '2023/hospitals_04_2023/Unplanned_Hospital_Visits-Hospital.csv',
           
           '2022/hospitals_01_2022/Unplanned_Hospital_Visits-Hospital.csv', 
           '2022/hospitals_04_2022/Unplanned_Hospital_Visits-Hospital.csv',
           '2022/hospitals_07_2022/Unplanned_Hospital_Visits-Hospital.csv',
           
           '2021/hospitals_01_2021/Unplanned_Hospital_Visits-Hospital.csv',
           '2021/hospitals_03_2021/Unplanned_Hospital_Visits-Hospital.csv',
           '2021/hospitals_04_2021/Unplanned_Hospital_Visits-Hospital.csv',
           '2021/hospitals_07_2021/Unplanned_Hospital_Visits-Hospital.csv',
           '2021/hospitals_10_2021/Unplanned_Hospital_Visits-Hospital.csv',
           
           '2020/hospitals_archive_10_2020/Unplanned_Hospital_Visits_Hospital.csv',
           '2020/hospitals_archive_07_2020/Unplanned_Hospital_Visits_Hospital.csv',
           '2020/HOSArchive_Revised_Flatfiles_20200422/Unplanned Hospital Visits - Hospital.csv',
           '2020/HOSArchive_Revised_Flatfiles_20200129/Unplanned Hospital Visits - Hospital.csv',
           
           '2019/HOSArchive_Revised_Flatfiles_20191030/Unplanned Hospital Visits - Hospital.csv',
           '2019/HOSArchive_Revised_Flatfiles_20190702/Unplanned Hospital Visits - Hospital.csv',
           '2019/HOSArchive_Revised_FlatFiles_20190424/Unplanned Hospital Visits - Hospital.csv',
           '2019/HOSArchive_Revised_Flatfiles_20190321/Unplanned Hospital Visits - Hospital.csv',
           
           '2018/HOSArchive_Revised_FlatFiles_20181031/Unplanned Hospital Visits - Hospital.csv',
           '2018/HOSArchive_Revised_FlatFiles_20180725/Unplanned Hospital Visits - Hospital.csv', 
           '2018/HOSArchive_Revised_FlatFiles_20180523/Unplanned Hospital Visits - Hospital.csv',
           '2018/HOSArchive_Revised_FlatFiles_20180126/Unplanned Hospital Visits - Hospital.csv',
           
           ]

for i, subdir in enumerate(subdirs):
    with io.capture_output() as captured: df = pd.read_csv(main_dir + subdir, encoding = "ISO-8859-1")
    print(subdir + ' :  (rows, columns) =', df.shape)
    df, lists = process2(df, lists, yrs[i], mos[i])
    df_list.append(df)

check_lists(lists)
subdir = 'Unplanned_Visits/CombinedFiles_Unplanned_Visits'
df = pd.concat(df_list)
print('df.shape:', df.shape)
# Out:
# 2023/hospitals_01_2023/Unplanned_Hospital_Visits-Hospital.csv :  (rows, columns) = (67872, 20)
# 2023/hospitals_04_2023/Unplanned_Hospital_Visits-Hospital.csv :  (rows, columns) = (67830, 20)
# 2022/hospitals_01_2022/Unplanned_Hospital_Visits-Hospital.csv :  (rows, columns) = (67872, 20)
# 2022/hospitals_04_2022/Unplanned_Hospital_Visits-Hospital.csv :  (rows, columns) = (67872, 20)
# 2022/hospitals_07_2022/Unplanned_Hospital_Visits-Hospital.csv :  (rows, columns) = (67802, 20)
# 2021/hospitals_01_2021/Unplanned_Hospital_Visits-Hospital.csv :  (rows, columns) = (68348, 20)
# 2021/hospitals_03_2021/Unplanned_Hospital_Visits-Hospital.csv :  (rows, columns) = (68348, 20)
# 2021/hospitals_04_2021/Unplanned_Hospital_Visits-Hospital.csv :  (rows, columns) = (68768, 20)
# 2021/hospitals_07_2021/Unplanned_Hospital_Visits-Hospital.csv :  (rows, columns) = (68124, 20)
# 2021/hospitals_10_2021/Unplanned_Hospital_Visits-Hospital.csv :  (rows, columns) = (67970, 20)
# 2020/hospitals_archive_10_2020/Unplanned_Hospital_Visits_Hospital.csv :  (rows, columns) = (68292, 20)
# 2020/hospitals_archive_07_2020/Unplanned_Hospital_Visits_Hospital.csv :  (rows, columns) = (68376, 20)
# 2020/HOSArchive_Revised_Flatfiles_20200422/Unplanned Hospital Visits - Hospital.csv :  (rows, columns) = (68407, 20)
# 2020/HOSArchive_Revised_Flatfiles_20200129/Unplanned Hospital Visits - Hospital.csv :  (rows, columns) = (68519, 18)
# 2019/HOSArchive_Revised_Flatfiles_20191030/Unplanned Hospital Visits - Hospital.csv :  (rows, columns) = (54082, 18)
# 2019/HOSArchive_Revised_Flatfiles_20190702/Unplanned Hospital Visits - Hospital.csv :  (rows, columns) = (54093, 18)
# 2019/HOSArchive_Revised_FlatFiles_20190424/Unplanned Hospital Visits - Hospital.csv :  (rows, columns) = (59191, 18)
# 2019/HOSArchive_Revised_Flatfiles_20190321/Unplanned Hospital Visits - Hospital.csv :  (rows, columns) = (59335, 18)
# 2018/HOSArchive_Revised_FlatFiles_20181031/Unplanned Hospital Visits - Hospital.csv :  (rows, columns) = (57924, 18)
# 2018/HOSArchive_Revised_FlatFiles_20180725/Unplanned Hospital Visits - Hospital.csv :  (rows, columns) = (57564, 20)
# 2018/HOSArchive_Revised_FlatFiles_20180523/Unplanned Hospital Visits - Hospital.csv :  (rows, columns) = (52778, 18)
# 2018/HOSArchive_Revised_FlatFiles_20180126/Unplanned Hospital Visits - Hospital.csv :  (rows, columns) = (52866, 18)
# df.shape: (1402233, 22)

# %%
df.drop(labels=['Address', 'City', 'County Name', 'Facility Name', 
                'End Date', 'Start Date', 'Footnote',
                'Phone Number', 'State', 'ZIP Code',
                'Compared to National', 'Higher Estimate', 'Lower Estimate',
                   ], axis=1, inplace=True)


df = df.filter(items=['Facility ID',
                      'file_month',
                      'file_year',
                      'Measure ID',
                      'Measure Name',
                      'Denominator', 
                      'Higher Estimate',
                      'Lower Estimate',
                      'Number of Patients',
                      'Number of Patients Returned',
                      'Score',
                     ], axis=1)

df.head()
# Out:
#   Facility ID file_month file_year   Measure ID  \
# 0      010001         01      2023  EDAC_30_AMI
# 1      010001         01      2023   EDAC_30_HF
# 2      010001         01      2023   EDAC_30_PN
# 3      010001         01      2023        OP_32
# 4      010001         01      2023    OP_35_ADM
#
#                                         Measure Name Denominator  \
# 0     Hospital return days for heart attack patients         319
# 1    Hospital return days for heart failure patients         755
# 2        Hospital return days for pneumonia patients         436
# 3  Rate of unplanned hospital visits after colono...         254
# 4  Rate of inpatient admissions for patients rece...         214
#
#   Number of Patients Number of Patients Returned Score
# 0                305                          81   1.9
# 1                618                         211  21.8
# 2                412                          99  -1.5
# 3     Not Applicable              Not Applicable  14.1
# 4     Not Applicable              Not Applicable  10.2

# %%
#print(df['Measure ID'].unique(), '\n')
#print(df['Measure Name'].unique(), '\n')

df['Measure'] = df['Measure ID'] + ' — ' + df['Measure Name']

measures = sorted(df['Measure'].unique())
for m in measures:
    print(m)
# Out:
# EDAC_30_AMI — Hospital return days for heart attack patients
# EDAC_30_HF — Hospital return days for heart failure patients
# EDAC_30_PN — Hospital return days for pneumonia patients
# OP-32 — Rate of unplanned hospital visits after colonoscopy (per 1,000 colonoscopies)
# OP_32 — Rate of unplanned hospital visits after colonoscopy (per 1,000 colonoscopies)
# OP_35_ADM — Rate of inpatient admissions for patients receiving outpatient chemotherapy
# OP_35_ED — Rate of emergency department (ED) visits for patients receiving outpatient chemotherapy
# OP_36 — Ratio of unplanned hospital visits after hospital outpatient surgery
# READM_30_AMI — Acute Myocardial Infarction (AMI) 30-Day Readmission Rate
# READM_30_AMI — Rate of readmission for heart attack patients
# READM_30_CABG — Rate of readmission for CABG
# READM_30_CABG — Rate of readmission for CABG surgery patients
# READM_30_COPD — Rate of readmission for chronic obstructive pulmonary disease (COPD) patients
# READM_30_HF — Heart failure (HF) 30-Day Readmission Rate
# READM_30_HF — Rate of readmission for heart failure patients
# READM_30_HIP_KNEE — Rate of readmission after hip/knee replacement
# READM_30_HOSP_WIDE — 30-Day Hospital-Wide All-Cause Unplanned Readmission Rate
# READM_30_HOSP_WIDE — Rate of readmission after discharge from hospital (hospital-wide)
# READM_30_PN — Pneumonia (PN) 30-Day Readmission Rate
# READM_30_PN — Rate of readmission for pneumonia patients
# READM_30_STK — Rate of readmission for stroke patients

# %%
d = {
    'EDAC_30_AMI — Hospital return days for heart attack patients': 'EDAC-30 AMI — Hospital return days for AMI patients', 
    'EDAC_30_HF — Hospital return days for heart failure patients': 'EDAC-30 HF — Hospital return days for HF patients',
    'EDAC_30_PN — Hospital return days for pneumonia patients': 'EDAC-30 PN — Hospital return days for PN patients', 
    'OP-32 — Rate of unplanned hospital visits after colonoscopy (per 1,000 colonoscopies)': 'OP-32 — Rate of unplanned visits after colonoscopy (per 1K)', 
    'OP_32 — Rate of unplanned hospital visits after colonoscopy (per 1,000 colonoscopies)': 'OP-32 — Rate of unplanned visits after colonoscopy (per 1K)',
    
    'OP_35_ADM — Rate of inpatient admissions for patients receiving outpatient chemotherapy': 'OP-35 ADM — Inpatient admit rate for patients receiving outpatient chemo', 
    'OP_35_ED — Rate of emergency department (ED) visits for patients receiving outpatient chemotherapy': 'OP-35 ED — ED visit rate for patients receiving outpatient chemo', 
    'OP_36 — Ratio of unplanned hospital visits after hospital outpatient surgery': 'OP-36 — Ratio of unplanned visits after outpatient surgery', 
    'READM_30_AMI — Acute Myocardial Infarction (AMI) 30-Day Readmission Rate': 'READM-30 AMI — AMI 30-Day Readmission Rate', 
    'READM_30_AMI — Rate of readmission for heart attack patients': 'READM-30 AMI — AMI 30-Day Readmission Rate',
    'READM_30_CABG — Rate of readmission for CABG': 'READM-30 CABG — CABG 30-Day Readmission Rate',
    'READM_30_CABG — Rate of readmission for CABG surgery patients': 'READM-30 CABG — CABG 30-Day Readmission Rate',
    
    'READM_30_COPD — Rate of readmission for chronic obstructive pulmonary disease (COPD) patients': 'READM-30 COPD — COPD 30-Day Readmission Rate', 
    
    'READM_30_HF — Heart failure (HF) 30-Day Readmission Rate': 'READM-30 HF — 30-Day HF Readmission Rate', 
    'READM_30_HF — Rate of readmission for heart failure patients': 'READM-30 HF — 30-Day HF Readmission Rate',
    
    'READM_30_HIP_KNEE — Rate of readmission after hip/knee replacement': 'READM-30 HIP-KNEE — 30-Day Readmission Rate after hip/knee replacement', 
    
    'READM_30_HOSP_WIDE — 30-Day Hospital-Wide All-Cause Unplanned Readmission Rate': 'READM-30 HOSP-WIDE — 30-Day Hospital-Wide All-Cause Unplanned Readmission Rate', 
    'READM_30_HOSP_WIDE — Rate of readmission after discharge from hospital (hospital-wide)': 'READM-30 HOSP-WIDE — 30-Day Hospital-Wide All-Cause Unplanned Readmission Rate',
    
    'READM_30_PN — Pneumonia (PN) 30-Day Readmission Rate': 'READM-30 PN — 30-Day Pneumonia Readmission Rate', 
    'READM_30_PN — Rate of readmission for pneumonia patients': 'READM-30 PN — 30-Day Pneumonia Readmission Rate',
    
    'READM_30_STK — Rate of readmission for stroke patients': 'READM-30 STK — 30-Day Readmission Rate for stroke patients',
}

df['Measure'].replace(to_replace=d, inplace=True)
print(df['Measure'].unique())
# Out:
# ['EDAC-30 AMI — Hospital return days for AMI patients'
#  'EDAC-30 HF — Hospital return days for HF patients'
#  'EDAC-30 PN — Hospital return days for PN patients'
#  'OP-32 — Rate of unplanned visits after colonoscopy (per 1K)'
#  'OP-35 ADM — Inpatient admit rate for patients receiving outpatient chemo'
#  'OP-35 ED — ED visit rate for patients receiving outpatient chemo'
#  'OP-36 — Ratio of unplanned visits after outpatient surgery'
#  'READM-30 AMI — AMI 30-Day Readmission Rate'
#  'READM-30 CABG — CABG 30-Day Readmission Rate'
#  'READM-30 COPD — COPD 30-Day Readmission Rate'
#  'READM-30 HF — 30-Day HF Readmission Rate'
#  'READM-30 HIP-KNEE — 30-Day Readmission Rate after hip/knee replacement'
#  'READM-30 HOSP-WIDE — 30-Day Hospital-Wide All-Cause Unplanned Readmission Rate'
#  'READM-30 PN — 30-Day Pneumonia Readmission Rate'
#  'READM-30 STK — 30-Day Readmission Rate for stroke patients']

# %%
df.drop(labels=['Measure Name', 'Measure ID'], axis=1, inplace=True)
df.head()
# Out:
#   Facility ID file_month file_year Denominator Number of Patients  \
# 0      010001         01      2023         319                305
# 1      010001         01      2023         755                618
# 2      010001         01      2023         436                412
# 3      010001         01      2023         254     Not Applicable
# 4      010001         01      2023         214     Not Applicable
#
#   Number of Patients Returned Score  \
# 0                          81   1.9
# 1                         211  21.8
# 2                          99  -1.5
# 3              Not Applicable  14.1
# 4              Not Applicable  10.2
#
#                                              Measure
# 0  EDAC-30 AMI — Hospital return days for AMI pat...
# 1  EDAC-30 HF — Hospital return days for HF patients
# 2  EDAC-30 PN — Hospital return days for PN patients
# 3  OP-32 — Rate of unplanned visits after colonos...
# 4  OP-35 ADM — Inpatient admit rate for patients ...

# %%
Measures = sorted(df['Measure'].unique())
main_df = pd.DataFrame(columns=['Facility ID', 'file_month', 'file_year'])

for i, mi in enumerate(Measures):
    
    tdf = df[df['Measure'] == mi]
    measures = sorted(tdf['Measure'].unique())
    
    df2 = pd.DataFrame(columns=['Facility ID', 'file_month', 'file_year'])

    for j, m in enumerate(measures):
    
        tdf2 = tdf[tdf['Measure'] == m]
        for n in list(tdf2):
            if n == 'Measure' or n in ['Facility ID', 'file_month', 'file_year']:
                continue

            else:
                tdf2[n] = pd.to_numeric(tdf2[n], errors='coerce')
                tdf2.rename(columns={n: m + ' (' + n + ')'}, inplace=True)
        
        tdf2.drop(labels=['Measure'], axis=1, inplace=True)
        
        df2 = df2.merge(tdf2, on=['Facility ID', 'file_month', 
                                          'file_year'], how='outer')
    
    main_df = main_df.merge(df2, on=['Facility ID', 'file_month', 
                                          'file_year'], how='outer')

# %%
del df2
df = main_df.copy(deep=True)
del main_df

print(df.shape)
#df = df.loc[:, ~df.T.duplicated(keep='first')]
#df.dropna(how='all', axis=1, inplace=True)
#print(df.shape)
df.head()
# Out:
# (107280, 63)
#   Facility ID file_month file_year  \
# 0      010001         01      2023
# 1      010005         01      2023
# 2      010006         01      2023
# 3      010007         01      2023
# 4      010008         01      2023
#
#    EDAC-30 AMI — Hospital return days for AMI patients (Denominator)  \
# 0                                              319.0
# 1                                               38.0
# 2                                              312.0
# 3                                                NaN
# 4                                                NaN
#
#    EDAC-30 AMI — Hospital return days for AMI patients (Number of Patients)  \
# 0                                              305.0
# 1                                               38.0
# 2                                              301.0
# 3                                                NaN
# 4                                                NaN
#
#    EDAC-30 AMI — Hospital return days for AMI patients (Number of Patients Returned)  \
# 0                                               81.0
# 1                                                9.0
# 2                                               80.0
# 3                                                NaN
# 4                                                NaN
#
#    EDAC-30 AMI — Hospital return days for AMI patients (Score)  \
# 0                                                1.9
# 1                                                4.7
# 2                                               25.9
# 3                                                NaN
# 4                                                NaN
#
#    EDAC-30 HF — Hospital return days for HF patients (Denominator)  \
# 0                                              755.0
# 1                                              157.0
# 2                                              550.0
# 3                                               51.0
# 4                                                NaN
#
#    EDAC-30 HF — Hospital return days for HF patients (Number of Patients)  \
# 0                                              618.0
# 1                                              145.0
# 2                                              456.0
# 3                                               44.0
# 4                                                NaN
#
#    EDAC-30 HF — Hospital return days for HF patients (Number of Patients Returned)  \
# 0                                              211.0
# 1                                               48.0
# 2                                              136.0
# 3                                               22.0
# 4                                                NaN
#
#    EDAC-30 HF — Hospital return days for HF patients (Score)  \
# 0                                               21.8
# 1                                                9.3
# 2                                               -2.3
# 3                                               36.3
# 4                                                NaN
#
#    EDAC-30 PN — Hospital return days for PN patients (Denominator)  \
# 0                                              436.0
# 1                                              361.0
# 2                                              538.0
# 3                                               99.0
# 4                                                NaN
#
#    EDAC-30 PN — Hospital return days for PN patients (Number of Patients)  \
# 0                                              412.0
# 1                                              328.0
# 2                                              499.0
# 3                                               91.0
# 4                                                NaN
#
#    EDAC-30 PN — Hospital return days for PN patients (Number of Patients Returned)  \
# 0                                               99.0
# 1                                               98.0
# 2                                              147.0
# 3                                               23.0
# 4                                                NaN
#
#    EDAC-30 PN — Hospital return days for PN patients (Score)  \
# 0                                               -1.5
# 1                                                2.2
# 2                                               42.3
# 3                                              -12.6
# 4                                                NaN
#
#    OP-32 — Rate of unplanned visits after colonoscopy (per 1K) (Denominator)  \
# 0                                              254.0
# 1                                              850.0
# 2                                             1505.0
# 3                                              118.0
# 4                                               62.0
#
#    OP-32 — Rate of unplanned visits after colonoscopy (per 1K) (Number of Patients)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    OP-32 — Rate of unplanned visits after colonoscopy (per 1K) (Number of Patients Returned)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    OP-32 — Rate of unplanned visits after colonoscopy (per 1K) (Score)  \
# 0                                               14.1
# 1                                               14.6
# 2                                               12.5
# 3                                               15.3
# 4                                               14.3
#
#    OP-35 ADM — Inpatient admit rate for patients receiving outpatient chemo (Denominator)  \
# 0                                              214.0
# 1                                              108.0
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    OP-35 ADM — Inpatient admit rate for patients receiving outpatient chemo (Number of Patients)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    OP-35 ADM — Inpatient admit rate for patients receiving outpatient chemo (Number of Patients Returned)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    OP-35 ADM — Inpatient admit rate for patients receiving outpatient chemo (Score)  \
# 0                                               10.2
# 1                                               11.1
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    OP-35 ED — ED visit rate for patients receiving outpatient chemo (Denominator)  \
# 0                                              214.0
# 1                                              108.0
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    OP-35 ED — ED visit rate for patients receiving outpatient chemo (Number of Patients)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    OP-35 ED — ED visit rate for patients receiving outpatient chemo (Number of Patients Returned)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    OP-35 ED — ED visit rate for patients receiving outpatient chemo (Score)  \
# 0                                                4.7
# 1                                                5.7
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    OP-36 — Ratio of unplanned visits after outpatient surgery (Denominator)  \
# 0                                              688.0
# 1                                              362.0
# 2                                              468.0
# 3                                               56.0
# 4                                                NaN
#
#    OP-36 — Ratio of unplanned visits after outpatient surgery (Number of Patients)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    OP-36 — Ratio of unplanned visits after outpatient surgery (Number of Patients Returned)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    OP-36 — Ratio of unplanned visits after outpatient surgery (Score)  \
# 0                                                1.0
# 1                                                0.9
# 2                                                1.1
# 3                                                1.0
# 4                                                NaN
#
#    READM-30 AMI — AMI 30-Day Readmission Rate (Denominator)  \
# 0                                              319.0
# 1                                               38.0
# 2                                              312.0
# 3                                                NaN
# 4                                                NaN
#
#    READM-30 AMI — AMI 30-Day Readmission Rate (Number of Patients)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    READM-30 AMI — AMI 30-Day Readmission Rate (Number of Patients Returned)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    READM-30 AMI — AMI 30-Day Readmission Rate (Score)  \
# 0                                               14.9
# 1                                               14.4
# 2                                               16.5
# 3                                                NaN
# 4                                                NaN
#
#    READM-30 CABG — CABG 30-Day Readmission Rate (Denominator)  \
# 0                                              165.0
# 1                                                NaN
# 2                                              109.0
# 3                                                NaN
# 4                                                NaN
#
#    READM-30 CABG — CABG 30-Day Readmission Rate (Number of Patients)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    READM-30 CABG — CABG 30-Day Readmission Rate (Number of Patients Returned)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    READM-30 CABG — CABG 30-Day Readmission Rate (Score)  \
# 0                                               11.7
# 1                                                NaN
# 2                                               15.6
# 3                                                NaN
# 4                                                NaN
#
#    READM-30 COPD — COPD 30-Day Readmission Rate (Denominator)  \
# 0                                              202.0
# 1                                              234.0
# 2                                              235.0
# 3                                               72.0
# 4                                                NaN
#
#    READM-30 COPD — COPD 30-Day Readmission Rate (Number of Patients)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    READM-30 COPD — COPD 30-Day Readmission Rate (Number of Patients Returned)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    READM-30 COPD — COPD 30-Day Readmission Rate (Score)  \
# 0                                               19.9
# 1                                               17.6
# 2                                               17.7
# 3                                               19.7
# 4                                                NaN
#
#    READM-30 HF — 30-Day HF Readmission Rate (Denominator)  \
# 0                                              755.0
# 1                                              157.0
# 2                                              550.0
# 3                                               51.0
# 4                                                NaN
#
#    READM-30 HF — 30-Day HF Readmission Rate (Number of Patients)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    READM-30 HF — 30-Day HF Readmission Rate (Number of Patients Returned)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    READM-30 HF — 30-Day HF Readmission Rate (Score)  \
# 0                                              22.4
# 1                                              21.4
# 2                                              20.0
# 3                                              23.7
# 4                                               NaN
#
#    READM-30 HIP-KNEE — 30-Day Readmission Rate after hip/knee replacement (Denominator)  \
# 0                                               98.0
# 1                                              178.0
# 2                                              246.0
# 3                                                NaN
# 4                                                NaN
#
#    READM-30 HIP-KNEE — 30-Day Readmission Rate after hip/knee replacement (Number of Patients)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    READM-30 HIP-KNEE — 30-Day Readmission Rate after hip/knee replacement (Number of Patients Returned)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    READM-30 HIP-KNEE — 30-Day Readmission Rate after hip/knee replacement (Score)  \
# 0                                                4.2
# 1                                                4.0
# 2                                                4.8
# 3                                                NaN
# 4                                                NaN
#
#    READM-30 HOSP-WIDE — 30-Day Hospital-Wide All-Cause Unplanned Readmission Rate (Denominator)  \
# 0                                             3058.0
# 1                                             1258.0
# 2                                             2555.0
# 3                                              272.0
# 4                                               93.0
#
#    READM-30 HOSP-WIDE — 30-Day Hospital-Wide All-Cause Unplanned Readmission Rate (Number of Patients)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    READM-30 HOSP-WIDE — 30-Day Hospital-Wide All-Cause Unplanned Readmission Rate (Number of Patients Returned)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    READM-30 HOSP-WIDE — 30-Day Hospital-Wide All-Cause Unplanned Readmission Rate (Score)  \
# 0                                               14.2
# 1                                               13.9
# 2                                               14.2
# 3                                               15.1
# 4                                               14.5
#
#    READM-30 PN — 30-Day Pneumonia Readmission Rate (Denominator)  \
# 0                                              436.0
# 1                                              361.0
# 2                                              538.0
# 3                                               99.0
# 4                                                NaN
#
#    READM-30 PN — 30-Day Pneumonia Readmission Rate (Number of Patients)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    READM-30 PN — 30-Day Pneumonia Readmission Rate (Number of Patients Returned)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    READM-30 PN — 30-Day Pneumonia Readmission Rate (Score)  \
# 0                                               16.4
# 1                                               16.7
# 2                                               19.5
# 3                                               16.4
# 4                                                NaN
#
#    READM-30 STK — 30-Day Readmission Rate for stroke patients (Denominator)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    READM-30 STK — 30-Day Readmission Rate for stroke patients (Number of Patients)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    READM-30 STK — 30-Day Readmission Rate for stroke patients (Number of Patients Returned)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    READM-30 STK — 30-Day Readmission Rate for stroke patients (Score)
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
for i, n in enumerate(list(df)):
    if n in ['Facility ID', 'file_month', 'file_year']:
        continue
            
    df.rename(columns={n: 'Unplanned Visits: ' + n}, inplace=True)
    
print(df.shape)
df.head()
# Out:
# (107280, 63)
#   Facility ID file_month file_year  \
# 0      010001         01      2023
# 1      010005         01      2023
# 2      010006         01      2023
# 3      010007         01      2023
# 4      010008         01      2023
#
#    Unplanned Visits: EDAC-30 AMI — Hospital return days for AMI patients (Denominator)  \
# 0                                              319.0
# 1                                               38.0
# 2                                              312.0
# 3                                                NaN
# 4                                                NaN
#
#    Unplanned Visits: EDAC-30 AMI — Hospital return days for AMI patients (Number of Patients)  \
# 0                                              305.0
# 1                                               38.0
# 2                                              301.0
# 3                                                NaN
# 4                                                NaN
#
#    Unplanned Visits: EDAC-30 AMI — Hospital return days for AMI patients (Number of Patients Returned)  \
# 0                                               81.0
# 1                                                9.0
# 2                                               80.0
# 3                                                NaN
# 4                                                NaN
#
#    Unplanned Visits: EDAC-30 AMI — Hospital return days for AMI patients (Score)  \
# 0                                                1.9
# 1                                                4.7
# 2                                               25.9
# 3                                                NaN
# 4                                                NaN
#
#    Unplanned Visits: EDAC-30 HF — Hospital return days for HF patients (Denominator)  \
# 0                                              755.0
# 1                                              157.0
# 2                                              550.0
# 3                                               51.0
# 4                                                NaN
#
#    Unplanned Visits: EDAC-30 HF — Hospital return days for HF patients (Number of Patients)  \
# 0                                              618.0
# 1                                              145.0
# 2                                              456.0
# 3                                               44.0
# 4                                                NaN
#
#    Unplanned Visits: EDAC-30 HF — Hospital return days for HF patients (Number of Patients Returned)  \
# 0                                              211.0
# 1                                               48.0
# 2                                              136.0
# 3                                               22.0
# 4                                                NaN
#
#    Unplanned Visits: EDAC-30 HF — Hospital return days for HF patients (Score)  \
# 0                                               21.8
# 1                                                9.3
# 2                                               -2.3
# 3                                               36.3
# 4                                                NaN
#
#    Unplanned Visits: EDAC-30 PN — Hospital return days for PN patients (Denominator)  \
# 0                                              436.0
# 1                                              361.0
# 2                                              538.0
# 3                                               99.0
# 4                                                NaN
#
#    Unplanned Visits: EDAC-30 PN — Hospital return days for PN patients (Number of Patients)  \
# 0                                              412.0
# 1                                              328.0
# 2                                              499.0
# 3                                               91.0
# 4                                                NaN
#
#    Unplanned Visits: EDAC-30 PN — Hospital return days for PN patients (Number of Patients Returned)  \
# 0                                               99.0
# 1                                               98.0
# 2                                              147.0
# 3                                               23.0
# 4                                                NaN
#
#    Unplanned Visits: EDAC-30 PN — Hospital return days for PN patients (Score)  \
# 0                                               -1.5
# 1                                                2.2
# 2                                               42.3
# 3                                              -12.6
# 4                                                NaN
#
#    Unplanned Visits: OP-32 — Rate of unplanned visits after colonoscopy (per 1K) (Denominator)  \
# 0                                              254.0
# 1                                              850.0
# 2                                             1505.0
# 3                                              118.0
# 4                                               62.0
#
#    Unplanned Visits: OP-32 — Rate of unplanned visits after colonoscopy (per 1K) (Number of Patients)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Unplanned Visits: OP-32 — Rate of unplanned visits after colonoscopy (per 1K) (Number of Patients Returned)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Unplanned Visits: OP-32 — Rate of unplanned visits after colonoscopy (per 1K) (Score)  \
# 0                                               14.1
# 1                                               14.6
# 2                                               12.5
# 3                                               15.3
# 4                                               14.3
#
#    Unplanned Visits: OP-35 ADM — Inpatient admit rate for patients receiving outpatient chemo (Denominator)  \
# 0                                              214.0
# 1                                              108.0
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Unplanned Visits: OP-35 ADM — Inpatient admit rate for patients receiving outpatient chemo (Number of Patients)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Unplanned Visits: OP-35 ADM — Inpatient admit rate for patients receiving outpatient chemo (Number of Patients Returned)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Unplanned Visits: OP-35 ADM — Inpatient admit rate for patients receiving outpatient chemo (Score)  \
# 0                                               10.2
# 1                                               11.1
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Unplanned Visits: OP-35 ED — ED visit rate for patients receiving outpatient chemo (Denominator)  \
# 0                                              214.0
# 1                                              108.0
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Unplanned Visits: OP-35 ED — ED visit rate for patients receiving outpatient chemo (Number of Patients)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Unplanned Visits: OP-35 ED — ED visit rate for patients receiving outpatient chemo (Number of Patients Returned)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Unplanned Visits: OP-35 ED — ED visit rate for patients receiving outpatient chemo (Score)  \
# 0                                                4.7
# 1                                                5.7
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Unplanned Visits: OP-36 — Ratio of unplanned visits after outpatient surgery (Denominator)  \
# 0                                              688.0
# 1                                              362.0
# 2                                              468.0
# 3                                               56.0
# 4                                                NaN
#
#    Unplanned Visits: OP-36 — Ratio of unplanned visits after outpatient surgery (Number of Patients)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Unplanned Visits: OP-36 — Ratio of unplanned visits after outpatient surgery (Number of Patients Returned)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Unplanned Visits: OP-36 — Ratio of unplanned visits after outpatient surgery (Score)  \
# 0                                                1.0
# 1                                                0.9
# 2                                                1.1
# 3                                                1.0
# 4                                                NaN
#
#    Unplanned Visits: READM-30 AMI — AMI 30-Day Readmission Rate (Denominator)  \
# 0                                              319.0
# 1                                               38.0
# 2                                              312.0
# 3                                                NaN
# 4                                                NaN
#
#    Unplanned Visits: READM-30 AMI — AMI 30-Day Readmission Rate (Number of Patients)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Unplanned Visits: READM-30 AMI — AMI 30-Day Readmission Rate (Number of Patients Returned)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Unplanned Visits: READM-30 AMI — AMI 30-Day Readmission Rate (Score)  \
# 0                                               14.9
# 1                                               14.4
# 2                                               16.5
# 3                                                NaN
# 4                                                NaN
#
#    Unplanned Visits: READM-30 CABG — CABG 30-Day Readmission Rate (Denominator)  \
# 0                                              165.0
# 1                                                NaN
# 2                                              109.0
# 3                                                NaN
# 4                                                NaN
#
#    Unplanned Visits: READM-30 CABG — CABG 30-Day Readmission Rate (Number of Patients)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Unplanned Visits: READM-30 CABG — CABG 30-Day Readmission Rate (Number of Patients Returned)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Unplanned Visits: READM-30 CABG — CABG 30-Day Readmission Rate (Score)  \
# 0                                               11.7
# 1                                                NaN
# 2                                               15.6
# 3                                                NaN
# 4                                                NaN
#
#    Unplanned Visits: READM-30 COPD — COPD 30-Day Readmission Rate (Denominator)  \
# 0                                              202.0
# 1                                              234.0
# 2                                              235.0
# 3                                               72.0
# 4                                                NaN
#
#    Unplanned Visits: READM-30 COPD — COPD 30-Day Readmission Rate (Number of Patients)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Unplanned Visits: READM-30 COPD — COPD 30-Day Readmission Rate (Number of Patients Returned)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Unplanned Visits: READM-30 COPD — COPD 30-Day Readmission Rate (Score)  \
# 0                                               19.9
# 1                                               17.6
# 2                                               17.7
# 3                                               19.7
# 4                                                NaN
#
#    Unplanned Visits: READM-30 HF — 30-Day HF Readmission Rate (Denominator)  \
# 0                                              755.0
# 1                                              157.0
# 2                                              550.0
# 3                                               51.0
# 4                                                NaN
#
#    Unplanned Visits: READM-30 HF — 30-Day HF Readmission Rate (Number of Patients)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Unplanned Visits: READM-30 HF — 30-Day HF Readmission Rate (Number of Patients Returned)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Unplanned Visits: READM-30 HF — 30-Day HF Readmission Rate (Score)  \
# 0                                               22.4
# 1                                               21.4
# 2                                               20.0
# 3                                               23.7
# 4                                                NaN
#
#    Unplanned Visits: READM-30 HIP-KNEE — 30-Day Readmission Rate after hip/knee replacement (Denominator)  \
# 0                                               98.0
# 1                                              178.0
# 2                                              246.0
# 3                                                NaN
# 4                                                NaN
#
#    Unplanned Visits: READM-30 HIP-KNEE — 30-Day Readmission Rate after hip/knee replacement (Number of Patients)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Unplanned Visits: READM-30 HIP-KNEE — 30-Day Readmission Rate after hip/knee replacement (Number of Patients Returned)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Unplanned Visits: READM-30 HIP-KNEE — 30-Day Readmission Rate after hip/knee replacement (Score)  \
# 0                                                4.2
# 1                                                4.0
# 2                                                4.8
# 3                                                NaN
# 4                                                NaN
#
#    Unplanned Visits: READM-30 HOSP-WIDE — 30-Day Hospital-Wide All-Cause Unplanned Readmission Rate (Denominator)  \
# 0                                             3058.0
# 1                                             1258.0
# 2                                             2555.0
# 3                                              272.0
# 4                                               93.0
#
#    Unplanned Visits: READM-30 HOSP-WIDE — 30-Day Hospital-Wide All-Cause Unplanned Readmission Rate (Number of Patients)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Unplanned Visits: READM-30 HOSP-WIDE — 30-Day Hospital-Wide All-Cause Unplanned Readmission Rate (Number of Patients Returned)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Unplanned Visits: READM-30 HOSP-WIDE — 30-Day Hospital-Wide All-Cause Unplanned Readmission Rate (Score)  \
# 0                                               14.2
# 1                                               13.9
# 2                                               14.2
# 3                                               15.1
# 4                                               14.5
#
#    Unplanned Visits: READM-30 PN — 30-Day Pneumonia Readmission Rate (Denominator)  \
# 0                                              436.0
# 1                                              361.0
# 2                                              538.0
# 3                                               99.0
# 4                                                NaN
#
#    Unplanned Visits: READM-30 PN — 30-Day Pneumonia Readmission Rate (Number of Patients)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Unplanned Visits: READM-30 PN — 30-Day Pneumonia Readmission Rate (Number of Patients Returned)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Unplanned Visits: READM-30 PN — 30-Day Pneumonia Readmission Rate (Score)  \
# 0                                               16.4
# 1                                               16.7
# 2                                               19.5
# 3                                               16.4
# 4                                                NaN
#
#    Unplanned Visits: READM-30 STK — 30-Day Readmission Rate for stroke patients (Denominator)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Unplanned Visits: READM-30 STK — 30-Day Readmission Rate for stroke patients (Number of Patients)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Unplanned Visits: READM-30 STK — 30-Day Readmission Rate for stroke patients (Number of Patients Returned)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Unplanned Visits: READM-30 STK — 30-Day Readmission Rate for stroke patients (Score)
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
df.to_pickle('dataframes/unplanned_visits_df.pkl.gz', protocol=5, compression='gzip')
