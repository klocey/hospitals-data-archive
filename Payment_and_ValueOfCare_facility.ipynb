# %% [markdown]
# # Generate Payment and Value of Care dataframe

# %%
import pandas as pd
import numpy as np
import warnings
from IPython.utils import io
import sys
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

main_dir = '/Users/kenlocey/Desktop/Rush/CMS_HospitalArchives/'

# %% [markdown]
# ## Define Custom Functions

# %%
def check_lists(lists):
    for i, ls in enumerate(lists):
        for i2, ls2 in enumerate(lists):
            for i3 in ls:
                if i3 not in ls2:
                    print('\n')
                    print(i3 + ': NOT FOUND IN')
                    print(ls2)
                    sys.exit()
                        
                        
def curate(df):

    try:
        df = df[df['Facility ID'] != np.nan]
        df['Facility ID'] = df['Facility ID'].values.astype(str)
        
        ids = df['Facility ID'].tolist()
        ids2 = []
        for i in ids:
            if len(i) < 6:
                i = '0' + i
            ids2.append(i)
        df['Facility ID'] = ids2
        
    except:
        pass
    try:
        df = df[df['Facility Name'] != np.nan]
    except:
        pass
    
    for c in list(df):    
        try:
            df[c] = df[c].str.replace("\t","")
        except:
            pass

    return df


def rename_and_fill(df):
    
    cols1 = ['Provider ID', "Measure Start Date", "Measure End Date",
             'Hospital Name', 'Hospital name', 'County name',
             'Phone number', 'Payment measure name', 'Payment measure ID', 
             'Payment category', 'Lower estimate', 'Higher estimate', 
             'Payment footnote', 'Value of care display name', 
             'Value of care display ID', 'Value of care category', 
             'Value of care footnote', 'Measure start date', 'Measure end date',
             'Start Date', 'End Date', 'Measure ID',
             'Measure name', 'Category', 'Footnote',
             ]
    
    
    cols2 = ['Facility ID', "Start Date", "End Date",
             'Facility Name', 'Facility Name', 'County Name',
             'Phone Number', 'Payment Measure Name', 'Payment Measure ID', 
             'Payment Category', 'Lower Estimate', 'Higher Estimate', 
             'Payment Footnote', 'Value of Care Display Name', 
             'Value of Care Display ID', 'Value of Care Category', 
             'Value of Care Footnote', 'Measure Start Date', 'Measure End Date',
             'Measure Start Date', 'Measure End Date', 'Payment Measure ID',
             'Payment Measure Name', 'Payment Category', 'Payment Footnote',
             
             ]
    
    for i, col in enumerate(cols1):
        if col in list(df):
            df.rename(columns={col: cols2[i]}, inplace=True)
            
            
    cols = ['Value of Care Display ID', 'Value of Care Display Name', 'Value of Care Category', 'Value of Care Footnote',
            ]
    
    for col in cols:
        if col not in list(df):
            df[col] = float('NaN')
    
    l = list(df)
    l = list(set([x for x in l if l.count(x) > 1]))
    if len(l) > 0:
        print('duplicates:', l)
        sys.exit()
        
    return df


def process2(df, lists, yr, mo):
    df = rename_and_fill(df)
    df = curate(df)
    lists.append(list(df))
    df['file_month'] = [mo]* df.shape[0]
    df['file_year'] = [yr]* df.shape[0]
    df = df.reindex(sorted(df.columns), axis=1)
    return df, lists

# %% [markdown]
# ## Load Files

# %%
df_list = []
lists = []

yrs = ['2023', '2023',
       '2022', '2022', '2022',
       '2021','2021','2021', '2021', '2021',
       '2020', '2020', '2020', '2020', 
       '2019', '2019', '2019', '2019', 
       '2018', '2018', '2018', '2018',
       '2017', '2017', '2017',
       '2016', '2016', '2016', '2016',
       '2015', '2015', '2015',
       ]

mos = ['01', '04',
       '01', '04', '07',
       '01', '03', '04', '07', '10', 
       '10', '07', '04', '01', 
       '10', '07', '04', '03', 
       '10', '07', '05', '01',
       '10', '07', '04',
       '12', '11', '08', '05',
       '12', '10', '07',
       ]

subdirs = ['2023/hospitals_01_2023/Payment_and_Value_of_Care-Hospital.csv', 
           '2023/hospitals_04_2023/Payment_and_Value_of_Care-Hospital.csv',
           
           '2022/hospitals_01_2022/Payment_and_Value_of_Care-Hospital.csv', 
           '2022/hospitals_04_2022/Payment_and_Value_of_Care-Hospital.csv',
           '2022/hospitals_07_2022/Payment_and_Value_of_Care-Hospital.csv',
           
           '2021/hospitals_01_2021/Payment_and_Value_of_Care-Hospital.csv',
           '2021/hospitals_03_2021/Payment_and_Value_of_Care-Hospital.csv',
           '2021/hospitals_04_2021/Payment_and_Value_of_Care-Hospital.csv',
           '2021/hospitals_07_2021/Payment_and_Value_of_Care-Hospital.csv',
           '2021/hospitals_10_2021/Payment_and_Value_of_Care-Hospital.csv',
           
           '2020/hospitals_archive_10_2020/Payment_and_value_of_care_Hospital.csv',
           '2020/hospitals_archive_07_2020/Payment_and_value_of_care_Hospital.csv',
           '2020/HOSArchive_Revised_Flatfiles_20200422/Payment and Value of Care - Hospital.csv',
           '2020/HOSArchive_Revised_Flatfiles_20200129/Payment and Value of Care - Hospital.csv',
           
           '2019/HOSArchive_Revised_Flatfiles_20191030/Payment and Value of Care - Hospital.csv',
           '2019/HOSArchive_Revised_Flatfiles_20190702/Payment and Value of Care - Hospital.csv',
           '2019/HOSArchive_Revised_FlatFiles_20190424/Payment and Value of Care - Hospital.csv',
           '2019/HOSArchive_Revised_Flatfiles_20190321/Payment and Value of Care - Hospital.csv',
           
           '2018/HOSArchive_Revised_FlatFiles_20181031/Payment and Value of Care - Hospital.csv',
           '2018/HOSArchive_Revised_FlatFiles_20180725/Payment and Value of Care - Hospital.csv', 
           '2018/HOSArchive_Revised_FlatFiles_20180523/Payment and Value of Care - Hospital.csv',
           '2018/HOSArchive_Revised_FlatFiles_20180126/Payment and Value of Care - Hospital.csv',
           
           '2017/HOSArchive_Revised_FlatFiles_20171024/Payment and Value of Care - Hospital.csv',
           '2017/HOSArchive_Revised_FlatFiles_20170726/Payment and Value of Care - Hospital.csv', 
           '2017/HOSArchive_Revised_Flatfiles_20170428/Payment and Value of Care - Hospital.csv', 
           
           '2016/HOSArchive_Revised_Flatfiles_20161219/Payment and Value of Care - Hospital.csv',
           '2016/Hospital_Revised_FlatFiles_20161110/Payment and Value of Care - Hospital.csv', 
           '2016/HOSArchive_Revised_FlatFiles_20160810/Payment and Value of Care - Hospital.csv',
           '2016/HOSArchive_Revised_FlatFiles_20160504/Payment and Value of Care - Hospital.csv',
           
           '2015/HOSArchive_Revised_FlatFiles_20151210/Payment and Value of Care - Hospital.csv',
           '2015/HOSArchive_Revised_FlatFiles_20151008/Payment and Value of Care - Hospital.csv',
           '2015/HOSArchive_Revised_FlatFiles_20150716/Payment - Hospital.csv',
           
           ]

for i, subdir in enumerate(subdirs):
    with io.capture_output() as captured: df = pd.read_csv(main_dir + subdir, encoding = "ISO-8859-1")
    print(subdir + ' :  (rows, columns) =', df.shape)
    df, lists = process2(df, lists, yrs[i], mos[i])
    df_list.append(df)

check_lists(lists)
subdir = 'Payment_and_ValueOfCare/CombinedFiles_Payment_and_ValueOfCare'
df = pd.concat(df_list)
print('df.shape:', df.shape)
# Out:
# 2023/hospitals_01_2023/Payment_and_Value_of_Care-Hospital.csv :  (rows, columns) = (18704, 22)
# 2023/hospitals_04_2023/Payment_and_Value_of_Care-Hospital.csv :  (rows, columns) = (18692, 22)
# 2022/hospitals_01_2022/Payment_and_Value_of_Care-Hospital.csv :  (rows, columns) = (18704, 22)
# 2022/hospitals_04_2022/Payment_and_Value_of_Care-Hospital.csv :  (rows, columns) = (18704, 22)
# 2022/hospitals_07_2022/Payment_and_Value_of_Care-Hospital.csv :  (rows, columns) = (18684, 22)
# 2021/hospitals_01_2021/Payment_and_Value_of_Care-Hospital.csv :  (rows, columns) = (18840, 22)
# 2021/hospitals_03_2021/Payment_and_Value_of_Care-Hospital.csv :  (rows, columns) = (18840, 22)
# 2021/hospitals_04_2021/Payment_and_Value_of_Care-Hospital.csv :  (rows, columns) = (18960, 22)
# 2021/hospitals_07_2021/Payment_and_Value_of_Care-Hospital.csv :  (rows, columns) = (18776, 22)
# 2021/hospitals_10_2021/Payment_and_Value_of_Care-Hospital.csv :  (rows, columns) = (18728, 22)
# 2020/hospitals_archive_10_2020/Payment_and_value_of_care_Hospital.csv :  (rows, columns) = (18824, 22)
# 2020/hospitals_archive_07_2020/Payment_and_value_of_care_Hospital.csv :  (rows, columns) = (18848, 22)
# 2020/HOSArchive_Revised_Flatfiles_20200422/Payment and Value of Care - Hospital.csv :  (rows, columns) = (18896, 22)
# 2020/HOSArchive_Revised_Flatfiles_20200129/Payment and Value of Care - Hospital.csv :  (rows, columns) = (18928, 22)
# 2019/HOSArchive_Revised_Flatfiles_20191030/Payment and Value of Care - Hospital.csv :  (rows, columns) = (19028, 22)
# 2019/HOSArchive_Revised_Flatfiles_20190702/Payment and Value of Care - Hospital.csv :  (rows, columns) = (19032, 22)
# 2019/HOSArchive_Revised_FlatFiles_20190424/Payment and Value of Care - Hospital.csv :  (rows, columns) = (19088, 22)
# 2019/HOSArchive_Revised_Flatfiles_20190321/Payment and Value of Care - Hospital.csv :  (rows, columns) = (19136, 22)
# 2018/HOSArchive_Revised_FlatFiles_20181031/Payment and Value of Care - Hospital.csv :  (rows, columns) = (19172, 22)
# 2018/HOSArchive_Revised_FlatFiles_20180725/Payment and Value of Care - Hospital.csv :  (rows, columns) = (19188, 22)
# 2018/HOSArchive_Revised_FlatFiles_20180523/Payment and Value of Care - Hospital.csv :  (rows, columns) = (19192, 22)
# 2018/HOSArchive_Revised_FlatFiles_20180126/Payment and Value of Care - Hospital.csv :  (rows, columns) = (19224, 22)
# 2017/HOSArchive_Revised_FlatFiles_20171024/Payment and Value of Care - Hospital.csv :  (rows, columns) = (19248, 22)
# 2017/HOSArchive_Revised_FlatFiles_20170726/Payment and Value of Care - Hospital.csv :  (rows, columns) = (19248, 22)
# 2017/HOSArchive_Revised_Flatfiles_20170428/Payment and Value of Care - Hospital.csv :  (rows, columns) = (14415, 22)
# 2016/HOSArchive_Revised_Flatfiles_20161219/Payment and Value of Care - Hospital.csv :  (rows, columns) = (14421, 22)
# 2016/Hospital_Revised_FlatFiles_20161110/Payment and Value of Care - Hospital.csv :  (rows, columns) = (14454, 22)
# 2016/HOSArchive_Revised_FlatFiles_20160810/Payment and Value of Care - Hospital.csv :  (rows, columns) = (13878, 22)
# 2016/HOSArchive_Revised_FlatFiles_20160504/Payment and Value of Care - Hospital.csv :  (rows, columns) = (14316, 22)
# 2015/HOSArchive_Revised_FlatFiles_20151210/Payment and Value of Care - Hospital.csv :  (rows, columns) = (14301, 22)
# 2015/HOSArchive_Revised_FlatFiles_20151008/Payment and Value of Care - Hospital.csv :  (rows, columns) = (14277, 22)
# 2015/HOSArchive_Revised_FlatFiles_20150716/Payment - Hospital.csv :  (rows, columns) = (14355, 18)
# df.shape: (569101, 24)

# %%
df.drop(labels=['Address', 'City', 'County Name', 'Facility Name', 
                    'Measure End Date', 'Measure Start Date', 'Payment Footnote',
                    'Phone Number', 'State', 'Value of Care Footnote', 'ZIP Code',
                   ], axis=1, inplace=True)

df = df.filter(items=['Facility ID', 
                        'file_month',
                        'file_year',
                        'Denominator', 
                        'Higher Estimate',
                        'Lower Estimate',
                        'Payment',
                        'Payment Category',
                        'Payment Measure ID',
                        'Payment Measure Name',
                        'Value of Care Category',
                        'Value of Care Display ID',
                        #'Value of Care Display Name',
                        ], axis=1)



df['Value of Care Display ID'].fillna('Not Available', inplace=True)
df['Value of Care Category'].fillna('Not Available', inplace=True)
df.head()
# Out:
#   Facility ID file_month file_year Denominator Higher Estimate Lower Estimate  \
# 0      010001         01      2023         311         $29,027        $24,890
# 1      010001         01      2023         620         $18,783        $16,947
# 2      010001         01      2023         397         $20,653        $19,430
# 3      010001         01      2023         101         $23,309        $20,104
# 4      010005         01      2023          48         $29,475        $22,668
#
#    Payment                                Payment Category Payment Measure ID  \
# 0  $26,894  No Different Than the National Average Payment        PAYM_30_AMI
# 1  $17,835  No Different Than the National Average Payment         PAYM_30_HF
# 2  $20,182  No Different Than the National Average Payment         PAYM_30_PN
# 3  $21,623  No Different Than the National Average Payment   PAYM_90_HIP_KNEE
# 4  $25,814  No Different Than the National Average Payment        PAYM_30_AMI
#
#                         Payment Measure Name  \
# 0          Payment for heart attack patients
# 1         Payment for heart failure patients
# 2             Payment for pneumonia patients
# 3  Payment for hip/knee replacement patients
# 4          Payment for heart attack patients
#
#                       Value of Care Category Value of Care Display ID
# 0      Average Mortality and Average Payment         MORT_PAYM_30_AMI
# 1       Better Mortality and Average Payment          MORT_PAYM_30_HF
# 2      Average Mortality and Average Payment          MORT_PAYM_30_PN
# 3  Average Complications and Average Payment    COMP_PAYM_90_HIP_KNEE
# 4      Average Mortality and Average Payment         MORT_PAYM_30_AMI

# %%
print(len(df['Payment Measure Name'].unique()))
print(df['Payment Measure Name'].unique())
print('\n')

print(len(df['Value of Care Display ID'].unique()))
print(df['Value of Care Display ID'].unique())
print('\n')

#print(len(pvc_df['Value of Care Category'].unique()))
#print(pvc_df['Value of Care Category'].unique())
#print('\n')

df['Measure'] = df['Value of Care Display ID'] + ' — ' + df['Payment Measure Name']
df.drop(labels=['Payment Measure Name', 'Value of Care Display ID'], axis=1, inplace=True)
# Out:
# 4
# ['Payment for heart attack patients' 'Payment for heart failure patients'
#  'Payment for pneumonia patients'
#  'Payment for hip/knee replacement patients']
#
#
# 5
# ['MORT_PAYM_30_AMI' 'MORT_PAYM_30_HF' 'MORT_PAYM_30_PN'
#  'COMP_PAYM_90_HIP_KNEE' 'Not Available']

# %%
    
d = {
    'Not Available — Payment for heart attack patients': 'MORT_PAYM_30_AMI — Payment for heart attack patients',
    'Not Available — Payment for heart failure patients': 'MORT_PAYM_30_HF — Payment for heart failure patients',
    'Not Available — Payment for pneumonia patients': 'MORT_PAYM_30_PN — Payment for pneumonia patients',    
    }  

df['Measure'].replace(to_replace=d, inplace=True)

measures = sorted(df['Measure'].unique())
for m in measures:
    print(m)
# Out:
# COMP_PAYM_90_HIP_KNEE — Payment for hip/knee replacement patients
# MORT_PAYM_30_AMI — Payment for heart attack patients
# MORT_PAYM_30_HF — Payment for heart failure patients
# MORT_PAYM_30_PN — Payment for pneumonia patients

# %%
measure_ids = sorted(df['Measure'].unique())
main_df = pd.DataFrame(columns=['Facility ID', 'file_month', 'file_year'])

for i, m_id in enumerate(measure_ids):
    
    tdf = df[df['Measure'] == m_id]
    measures = sorted(tdf['Measure'].unique())
    
    df2 = pd.DataFrame(columns=['Facility ID', 'file_month', 'file_year'])

    for j, m in enumerate(measures):
    
        tdf2 = tdf[tdf['Measure'] == m]
        for n in list(tdf2):
            if n == 'Measure' or n in ['Facility ID', 'file_month', 'file_year']:
                continue

            else:
                
                if n == 'Denominator':                
                    tdf2[n] = pd.to_numeric(tdf2[n], errors='coerce')
                
                elif n in ['Higher Estimate', 'Lower Estimate', 'Payment']:
                    tdf2[n] = tdf2[n].replace("[$,]", "", regex=True)
                    tdf2[n] = pd.to_numeric(tdf2[n], errors='coerce')
                
                tdf2.rename(columns={n: m + ' (' + n + ')'}, inplace=True)
        
        tdf2.drop(labels=['Measure'], axis=1, inplace=True)
        
        df2 = df2.merge(tdf2, on=['Facility ID', 'file_month', 
                                          'file_year'], how='outer')
    
    main_df = main_df.merge(df2, on=['Facility ID', 'file_month', 
                                          'file_year'], how='outer')


df = main_df.copy(deep=True)
del main_df, df2
print(df.shape)
df.dropna(how='all', axis=1, inplace=True)
print(df.shape)
df.head()
# Out:
# (151810, 31)
# (151810, 31)
#   Facility ID file_month file_year  \
# 0      010001         01      2023
# 1      010005         01      2023
# 2      010006         01      2023
# 3      010007         01      2023
# 4      010008         01      2023
#
#    COMP_PAYM_90_HIP_KNEE — Payment for hip/knee replacement patients (Denominator)  \
# 0                                              101.0
# 1                                              133.0
# 2                                              232.0
# 3                                                NaN
# 4                                                NaN
#
#    COMP_PAYM_90_HIP_KNEE — Payment for hip/knee replacement patients (Higher Estimate)  \
# 0                                            23309.0
# 1                                            20281.0
# 2                                            23148.0
# 3                                                NaN
# 4                                                NaN
#
#    COMP_PAYM_90_HIP_KNEE — Payment for hip/knee replacement patients (Lower Estimate)  \
# 0                                            20104.0
# 1                                            17873.0
# 2                                            20905.0
# 3                                                NaN
# 4                                                NaN
#
#    COMP_PAYM_90_HIP_KNEE — Payment for hip/knee replacement patients (Payment)  \
# 0                                            21623.0
# 1                                            19040.0
# 2                                            21994.0
# 3                                                NaN
# 4                                                NaN
#
#   COMP_PAYM_90_HIP_KNEE — Payment for hip/knee replacement patients (Payment Category)  \
# 0     No Different Than the National Average Payment
# 1             Less Than the National Average Payment
# 2          Greater Than the National Average Payment
# 3                          Number of Cases Too Small
# 4                                      Not Available
#
#   COMP_PAYM_90_HIP_KNEE — Payment for hip/knee replacement patients (Payment Measure ID)  \
# 0                                   PAYM_90_HIP_KNEE
# 1                                   PAYM_90_HIP_KNEE
# 2                                   PAYM_90_HIP_KNEE
# 3                                   PAYM_90_HIP_KNEE
# 4                                   PAYM_90_HIP_KNEE
#
#   COMP_PAYM_90_HIP_KNEE — Payment for hip/knee replacement patients (Value of Care Category)  \
# 0          Average Complications and Average Payment
# 1            Average Complications and Lower Payment
# 2           Average Complications and Higher Payment
# 3                                      Not Available
# 4                                      Not Available
#
#    MORT_PAYM_30_AMI — Payment for heart attack patients (Denominator)  \
# 0                                              311.0
# 1                                               48.0
# 2                                              287.0
# 3                                                NaN
# 4                                                NaN
#
#    MORT_PAYM_30_AMI — Payment for heart attack patients (Higher Estimate)  \
# 0                                            29027.0
# 1                                            29475.0
# 2                                            30977.0
# 3                                                NaN
# 4                                                NaN
#
#    MORT_PAYM_30_AMI — Payment for heart attack patients (Lower Estimate)  \
# 0                                            24890.0
# 1                                            22668.0
# 2                                            26395.0
# 3                                                NaN
# 4                                                NaN
#
#    MORT_PAYM_30_AMI — Payment for heart attack patients (Payment)  \
# 0                                            26894.0
# 1                                            25814.0
# 2                                            28589.0
# 3                                                NaN
# 4                                                NaN
#
#   MORT_PAYM_30_AMI — Payment for heart attack patients (Payment Category)  \
# 0     No Different Than the National Average Payment
# 1     No Different Than the National Average Payment
# 2     No Different Than the National Average Payment
# 3                          Number of Cases Too Small
# 4                          Number of Cases Too Small
#
#   MORT_PAYM_30_AMI — Payment for heart attack patients (Payment Measure ID)  \
# 0                                        PAYM_30_AMI
# 1                                        PAYM_30_AMI
# 2                                        PAYM_30_AMI
# 3                                        PAYM_30_AMI
# 4                                        PAYM_30_AMI
#
#   MORT_PAYM_30_AMI — Payment for heart attack patients (Value of Care Category)  \
# 0              Average Mortality and Average Payment
# 1              Average Mortality and Average Payment
# 2                Worse Mortality and Average Payment
# 3                                      Not Available
# 4                                      Not Available
#
#    MORT_PAYM_30_HF — Payment for heart failure patients (Denominator)  \
# 0                                              620.0
# 1                                              142.0
# 2                                              451.0
# 3                                               43.0
# 4                                                NaN
#
#    MORT_PAYM_30_HF — Payment for heart failure patients (Higher Estimate)  \
# 0                                            18783.0
# 1                                            19040.0
# 2                                            19918.0
# 3                                            19839.0
# 4                                                NaN
#
#    MORT_PAYM_30_HF — Payment for heart failure patients (Lower Estimate)  \
# 0                                            16947.0
# 1                                            15749.0
# 2                                            17693.0
# 3                                            15128.0
# 4                                                NaN
#
#    MORT_PAYM_30_HF — Payment for heart failure patients (Payment)  \
# 0                                            17835.0
# 1                                            17287.0
# 2                                            18745.0
# 3                                            17397.0
# 4                                                NaN
#
#   MORT_PAYM_30_HF — Payment for heart failure patients (Payment Category)  \
# 0     No Different Than the National Average Payment
# 1     No Different Than the National Average Payment
# 2     No Different Than the National Average Payment
# 3     No Different Than the National Average Payment
# 4                          Number of Cases Too Small
#
#   MORT_PAYM_30_HF — Payment for heart failure patients (Payment Measure ID)  \
# 0                                         PAYM_30_HF
# 1                                         PAYM_30_HF
# 2                                         PAYM_30_HF
# 3                                         PAYM_30_HF
# 4                                         PAYM_30_HF
#
#   MORT_PAYM_30_HF — Payment for heart failure patients (Value of Care Category)  \
# 0               Better Mortality and Average Payment
# 1                Worse Mortality and Average Payment
# 2              Average Mortality and Average Payment
# 3              Average Mortality and Average Payment
# 4                                      Not Available
#
#    MORT_PAYM_30_PN — Payment for pneumonia patients (Denominator)  \
# 0                                              397.0
# 1                                              343.0
# 2                                              511.0
# 3                                              101.0
# 4                                                NaN
#
#    MORT_PAYM_30_PN — Payment for pneumonia patients (Higher Estimate)  \
# 0                                            20653.0
# 1                                            19563.0
# 2                                            20779.0
# 3                                            19791.0
# 4                                                NaN
#
#    MORT_PAYM_30_PN — Payment for pneumonia patients (Lower Estimate)  \
# 0                                            19430.0
# 1                                            18407.0
# 2                                            19452.0
# 3                                            18753.0
# 4                                                NaN
#
#    MORT_PAYM_30_PN — Payment for pneumonia patients (Payment)  \
# 0                                            20182.0
# 1                                            18639.0
# 2                                            20218.0
# 3                                            19222.0
# 4                                                NaN
#
#   MORT_PAYM_30_PN — Payment for pneumonia patients (Payment Category)  \
# 0     No Different Than the National Average Payment
# 1     No Different Than the National Average Payment
# 2     No Different Than the National Average Payment
# 3     No Different Than the National Average Payment
# 4                          Number of Cases Too Small
#
#   MORT_PAYM_30_PN — Payment for pneumonia patients (Payment Measure ID)  \
# 0                                         PAYM_30_PN
# 1                                         PAYM_30_PN
# 2                                         PAYM_30_PN
# 3                                         PAYM_30_PN
# 4                                         PAYM_30_PN
#
#   MORT_PAYM_30_PN — Payment for pneumonia patients (Value of Care Category)
# 0              Average Mortality and Average Payment
# 1                Worse Mortality and Average Payment
# 2              Average Mortality and Average Payment
# 3              Average Mortality and Average Payment
# 4                                      Not Available

# %%
for i, n in enumerate(list(df)):
    if n in ['Facility ID', 'file_month', 'file_year']:
        continue
            
    df.rename(columns={n: 'Payment and Value of Care: ' + n}, inplace=True)
    
print(df.shape)
df.head()
# Out:
# (151810, 31)
#   Facility ID file_month file_year  \
# 0      010001         01      2023
# 1      010005         01      2023
# 2      010006         01      2023
# 3      010007         01      2023
# 4      010008         01      2023
#
#    Payment and Value of Care: COMP_PAYM_90_HIP_KNEE — Payment for hip/knee replacement patients (Denominator)  \
# 0                                              101.0
# 1                                              133.0
# 2                                              232.0
# 3                                                NaN
# 4                                                NaN
#
#    Payment and Value of Care: COMP_PAYM_90_HIP_KNEE — Payment for hip/knee replacement patients (Higher Estimate)  \
# 0                                            23309.0
# 1                                            20281.0
# 2                                            23148.0
# 3                                                NaN
# 4                                                NaN
#
#    Payment and Value of Care: COMP_PAYM_90_HIP_KNEE — Payment for hip/knee replacement patients (Lower Estimate)  \
# 0                                            20104.0
# 1                                            17873.0
# 2                                            20905.0
# 3                                                NaN
# 4                                                NaN
#
#    Payment and Value of Care: COMP_PAYM_90_HIP_KNEE — Payment for hip/knee replacement patients (Payment)  \
# 0                                            21623.0
# 1                                            19040.0
# 2                                            21994.0
# 3                                                NaN
# 4                                                NaN
#
#   Payment and Value of Care: COMP_PAYM_90_HIP_KNEE — Payment for hip/knee replacement patients (Payment Category)  \
# 0     No Different Than the National Average Payment
# 1             Less Than the National Average Payment
# 2          Greater Than the National Average Payment
# 3                          Number of Cases Too Small
# 4                                      Not Available
#
#   Payment and Value of Care: COMP_PAYM_90_HIP_KNEE — Payment for hip/knee replacement patients (Payment Measure ID)  \
# 0                                   PAYM_90_HIP_KNEE
# 1                                   PAYM_90_HIP_KNEE
# 2                                   PAYM_90_HIP_KNEE
# 3                                   PAYM_90_HIP_KNEE
# 4                                   PAYM_90_HIP_KNEE
#
#   Payment and Value of Care: COMP_PAYM_90_HIP_KNEE — Payment for hip/knee replacement patients (Value of Care Category)  \
# 0          Average Complications and Average Payment
# 1            Average Complications and Lower Payment
# 2           Average Complications and Higher Payment
# 3                                      Not Available
# 4                                      Not Available
#
#    Payment and Value of Care: MORT_PAYM_30_AMI — Payment for heart attack patients (Denominator)  \
# 0                                              311.0
# 1                                               48.0
# 2                                              287.0
# 3                                                NaN
# 4                                                NaN
#
#    Payment and Value of Care: MORT_PAYM_30_AMI — Payment for heart attack patients (Higher Estimate)  \
# 0                                            29027.0
# 1                                            29475.0
# 2                                            30977.0
# 3                                                NaN
# 4                                                NaN
#
#    Payment and Value of Care: MORT_PAYM_30_AMI — Payment for heart attack patients (Lower Estimate)  \
# 0                                            24890.0
# 1                                            22668.0
# 2                                            26395.0
# 3                                                NaN
# 4                                                NaN
#
#    Payment and Value of Care: MORT_PAYM_30_AMI — Payment for heart attack patients (Payment)  \
# 0                                            26894.0
# 1                                            25814.0
# 2                                            28589.0
# 3                                                NaN
# 4                                                NaN
#
#   Payment and Value of Care: MORT_PAYM_30_AMI — Payment for heart attack patients (Payment Category)  \
# 0     No Different Than the National Average Payment
# 1     No Different Than the National Average Payment
# 2     No Different Than the National Average Payment
# 3                          Number of Cases Too Small
# 4                          Number of Cases Too Small
#
#   Payment and Value of Care: MORT_PAYM_30_AMI — Payment for heart attack patients (Payment Measure ID)  \
# 0                                        PAYM_30_AMI
# 1                                        PAYM_30_AMI
# 2                                        PAYM_30_AMI
# 3                                        PAYM_30_AMI
# 4                                        PAYM_30_AMI
#
#   Payment and Value of Care: MORT_PAYM_30_AMI — Payment for heart attack patients (Value of Care Category)  \
# 0              Average Mortality and Average Payment
# 1              Average Mortality and Average Payment
# 2                Worse Mortality and Average Payment
# 3                                      Not Available
# 4                                      Not Available
#
#    Payment and Value of Care: MORT_PAYM_30_HF — Payment for heart failure patients (Denominator)  \
# 0                                              620.0
# 1                                              142.0
# 2                                              451.0
# 3                                               43.0
# 4                                                NaN
#
#    Payment and Value of Care: MORT_PAYM_30_HF — Payment for heart failure patients (Higher Estimate)  \
# 0                                            18783.0
# 1                                            19040.0
# 2                                            19918.0
# 3                                            19839.0
# 4                                                NaN
#
#    Payment and Value of Care: MORT_PAYM_30_HF — Payment for heart failure patients (Lower Estimate)  \
# 0                                            16947.0
# 1                                            15749.0
# 2                                            17693.0
# 3                                            15128.0
# 4                                                NaN
#
#    Payment and Value of Care: MORT_PAYM_30_HF — Payment for heart failure patients (Payment)  \
# 0                                            17835.0
# 1                                            17287.0
# 2                                            18745.0
# 3                                            17397.0
# 4                                                NaN
#
#   Payment and Value of Care: MORT_PAYM_30_HF — Payment for heart failure patients (Payment Category)  \
# 0     No Different Than the National Average Payment
# 1     No Different Than the National Average Payment
# 2     No Different Than the National Average Payment
# 3     No Different Than the National Average Payment
# 4                          Number of Cases Too Small
#
#   Payment and Value of Care: MORT_PAYM_30_HF — Payment for heart failure patients (Payment Measure ID)  \
# 0                                         PAYM_30_HF
# 1                                         PAYM_30_HF
# 2                                         PAYM_30_HF
# 3                                         PAYM_30_HF
# 4                                         PAYM_30_HF
#
#   Payment and Value of Care: MORT_PAYM_30_HF — Payment for heart failure patients (Value of Care Category)  \
# 0               Better Mortality and Average Payment
# 1                Worse Mortality and Average Payment
# 2              Average Mortality and Average Payment
# 3              Average Mortality and Average Payment
# 4                                      Not Available
#
#    Payment and Value of Care: MORT_PAYM_30_PN — Payment for pneumonia patients (Denominator)  \
# 0                                              397.0
# 1                                              343.0
# 2                                              511.0
# 3                                              101.0
# 4                                                NaN
#
#    Payment and Value of Care: MORT_PAYM_30_PN — Payment for pneumonia patients (Higher Estimate)  \
# 0                                            20653.0
# 1                                            19563.0
# 2                                            20779.0
# 3                                            19791.0
# 4                                                NaN
#
#    Payment and Value of Care: MORT_PAYM_30_PN — Payment for pneumonia patients (Lower Estimate)  \
# 0                                            19430.0
# 1                                            18407.0
# 2                                            19452.0
# 3                                            18753.0
# 4                                                NaN
#
#    Payment and Value of Care: MORT_PAYM_30_PN — Payment for pneumonia patients (Payment)  \
# 0                                            20182.0
# 1                                            18639.0
# 2                                            20218.0
# 3                                            19222.0
# 4                                                NaN
#
#   Payment and Value of Care: MORT_PAYM_30_PN — Payment for pneumonia patients (Payment Category)  \
# 0     No Different Than the National Average Payment
# 1     No Different Than the National Average Payment
# 2     No Different Than the National Average Payment
# 3     No Different Than the National Average Payment
# 4                          Number of Cases Too Small
#
#   Payment and Value of Care: MORT_PAYM_30_PN — Payment for pneumonia patients (Payment Measure ID)  \
# 0                                         PAYM_30_PN
# 1                                         PAYM_30_PN
# 2                                         PAYM_30_PN
# 3                                         PAYM_30_PN
# 4                                         PAYM_30_PN
#
#   Payment and Value of Care: MORT_PAYM_30_PN — Payment for pneumonia patients (Value of Care Category)
# 0              Average Mortality and Average Payment
# 1                Worse Mortality and Average Payment
# 2              Average Mortality and Average Payment
# 3              Average Mortality and Average Payment
# 4                                      Not Available

# %%
df.to_pickle('dataframes/Payment_and_ValueOfCare_df.pkl.gz', protocol=5, compression='gzip')
